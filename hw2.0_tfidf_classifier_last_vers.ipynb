# %% [markdown]
# # Homework 2 - TF-IDF Classifier
#
# Ваша цель обучить классификатор который будет находить "токсичные" комментарии и опубликовать решения на Kaggle [Toxic Comment Classification Challenge](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge)
#
# В процессе обучения нужно ответить на ***[вопросы](https://docs.google.com/forms/d/e/1FAIpQLSd9mQx8EFpSH6FhCy1M_FmISzy3lhgyyqV3TN0pmtop7slmTA/viewform?usp=sf_link)***
#
# Данные можно скачать тут - https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge/data

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from scipy.sparse import hstack

# %%
class_names = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

train = pd.read_csv('train.csv').fillna(' ')
test = pd.read_csv('test.csv').fillna(' ')

# %% [markdown]
# Стадартными подходами для анализа текста являются [Bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) и его модификация [TF-IDF](https://en.wikipedia.org/wiki/Tf%E2%80%93idf).
#
# Они реалзованны в `sklearn` в виде [CountVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) и [TfidfVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html).
#
# Более подробней про них можно посмотреть [тут](https://github.com/udsclub/workshop/blob/master/notebooks/UDS-workshop-feature-extraction-and-engineering.ipynb)

# %%
train_text = train['comment_text']
test_text = test['comment_text']
all_text = pd.concat([train_text, test_text])

# %%
all_text = all_text.apply(str.lower)
train_text = train_text.apply(str.lower)
test_text = test_text.apply(str.lower)

# %%
# TASK1 FINDING THE MOST POPULAR WORD
# looking for the list of 20 most popular words
print(pd.Series(' '.join(all_text).lower().split()).value_counts()[:20].to_string())
# Out:
# the     902050
# to      532403
# of      406605
# a       399980
# and     397026
# i       342269
# you     333262
# is      323691
# that    267385
# in      259696
# it      202532
# for     181740
# this    162853
# not     158934
# "       157806
# on      155849
# be      150192
# as      136236
# are     128645
# have    126235

# %%
# TASK2 C PARAMETER IN LogReg
print('From python documentation: ')
print('C : float, default: 1.0')
print('Inverse of regularization strength; must be a positive float. Like in support vector machines, smaller values specify stronger regularization.')
# Out:
# From python documentation:
# C : float, default: 1.0
# Inverse of regularization strength; must be a positive float. Like in support vector machines, smaller values specify stronger regularization.

# %%
# SEARCHING THE BEST SET OF PARAMETERS WHEN  tfidf__max_features IN np.arange(1000, 35000, 8000)

total_score = []

df_res = pd.DataFrame(columns=class_names)
df_res = df_res.append({class_name: cv_score}, ignore_index=True)

for tfidf__max_df in np.arange(0.8, 1.1, 0.1):
    for tfidf__max_features in np.arange(1000, 35000, 8000):
        for tfidf__ngram_range in ((1, 1), (1, 2)):
            for lr__C in [0.9,1,3,5,10]:
                word_vectorizer = TfidfVectorizer(
                    analyzer='word', 
                    ngram_range=tfidf__ngram_range, 
                    vocabulary=None, 
                    max_df=tfidf__max_df,
                    max_features=tfidf__max_features, 
                    smooth_idf=True,
                    norm='l2' 
                    )


                classifier = LogisticRegression(penalty = 'l2', C = lr__C,max_iter = 1000)
                
                word_vectorizer.fit(all_text)
                train_word_features = word_vectorizer.transform(train_text)
                test_word_features = word_vectorizer.transform(test_text)
                
                scores= []
                d={}
                #d = dict.fromkeys(['a', 'b'])
                for class_name in class_names:
                    train_target = train[class_name]

                    cv_score = np.mean(cross_val_score(classifier, train_word_features, train_target, scoring='roc_auc'))
                    
                    
                    print('CV score for class {} is {}'.format(class_name, cv_score))
                    
                    d[class_name] = cv_score
                    
                    
                    scores.append(cv_score)
                df_res = df_res.append(d, ignore_index=True)
                d.clear()
                #print(df_res)
                print('ITERATION:  ',len(total_score))
                print('Parameters  ',tfidf__max_df,'  ',tfidf__max_features,'   ',tfidf__ngram_range,'  ',lr__C)
                total_score.append(np.mean(scores))
                print('Total score is {}'.format(np.mean(scores)))
# Out:
# CV score for class toxic is 0.9488783969088379
# CV score for class severe_toxic is 0.9787903595638028
# CV score for class obscene is 0.9708751938217719
# CV score for class threat is 0.9806301963198457
# CV score for class insult is 0.9597272327776771
# CV score for class identity_hate is 0.9570001310598428
# ITERATION:   0
# Parameters   0.8    1000     (1, 1)    0.9
# Total score is 0.9659835850752964
# CV score for class toxic is 0.9489345006635187
# CV score for class severe_toxic is 0.9787558968210993
# CV score for class obscene is 0.9708815563509644
# CV score for class threat is 0.9808318267336373
# CV score for class insult is 0.9596572687514041
# CV score for class identity_hate is 0.9569165006691582
# ITERATION:   1
# Parameters   0.8    1000     (1, 1)    1
# Total score is 0.9659962583316304
# CV score for class toxic is 0.9488103271385269
# CV score for class severe_toxic is 0.9773974603011654
# CV score for class obscene is 0.9699542675884641
# CV score for class threat is 0.9803719702662345
# CV score for class insult is 0.9582429903589081
# CV score for class identity_hate is 0.9542483593811397
# ITERATION:   2
# Parameters   0.8    1000     (1, 1)    3
# Total score is 0.9648375625057398
# CV score for class toxic is 0.9485350809687626
# CV score for class severe_toxic is 0.9762759347006412
# CV score for class obscene is 0.9691589325346758
# CV score for class threat is 0.9786725790790776
# CV score for class insult is 0.9574100329748524
# CV score for class identity_hate is 0.9521419661217995
# ITERATION:   3
# Parameters   0.8    1000     (1, 1)    5
# Total score is 0.9636990877299682
# CV score for class toxic is 0.9481502868670937
# CV score for class severe_toxic is 0.9743995224211542
# CV score for class obscene is 0.9680307825319185
# CV score for class threat is 0.9750407102129298
# CV score for class insult is 0.9563380454360305
# CV score for class identity_hate is 0.9487515773107275
# ITERATION:   4
# Parameters   0.8    1000     (1, 1)    10
# Total score is 0.9617851541299758
# CV score for class toxic is 0.9375349835375028
# CV score for class severe_toxic is 0.975938147438554
# CV score for class obscene is 0.9581609184066527
# CV score for class threat is 0.9676506191772171
# CV score for class insult is 0.9489283485971217
# CV score for class identity_hate is 0.9444568967391295
# ITERATION:   5
# Parameters   0.8    1000     (1, 2)    0.9
# Total score is 0.955444985649363
# CV score for class toxic is 0.9375892742131202
# CV score for class severe_toxic is 0.9758660637131604
# CV score for class obscene is 0.9581319001759256
# CV score for class threat is 0.9679022169037476
# CV score for class insult is 0.9488287236971663
# CV score for class identity_hate is 0.9443186288723454
# ITERATION:   6
# Parameters   0.8    1000     (1, 2)    1
# Total score is 0.9554394679292443
# CV score for class toxic is 0.9375279852089894
# CV score for class severe_toxic is 0.9740825844256955
# CV score for class obscene is 0.9568955728062895
# CV score for class threat is 0.9674444872727226
# CV score for class insult is 0.9470256871001214
# CV score for class identity_hate is 0.9410965396380587
# ITERATION:   7
# Parameters   0.8    1000     (1, 2)    3
# Total score is 0.9540121427419795
# CV score for class toxic is 0.9373069107626835
# CV score for class severe_toxic is 0.9726845909098771
# CV score for class obscene is 0.9559965627832999
# CV score for class threat is 0.9654196794954433
# CV score for class insult is 0.9459969857569231
# CV score for class identity_hate is 0.9387979961882243
# ITERATION:   8
# Parameters   0.8    1000     (1, 2)    5
# Total score is 0.9527004543160752
# CV score for class toxic is 0.9369811497508582
# CV score for class severe_toxic is 0.970371770927453
# CV score for class obscene is 0.9547933429389818
# CV score for class threat is 0.9611372771531085
# CV score for class insult is 0.9446985012530099
# CV score for class identity_hate is 0.9351982082801357
# ITERATION:   9
# Parameters   0.8    1000     (1, 2)    10
# Total score is 0.9505300417172579
# CV score for class toxic is 0.9687992076438979
# CV score for class severe_toxic is 0.9830693770362776
# CV score for class obscene is 0.9813601732132998
# CV score for class threat is 0.984210289024611
# CV score for class insult is 0.9747840298708232
# CV score for class identity_hate is 0.9711519562853255
# ITERATION:   10
# Parameters   0.8    9000     (1, 1)    0.9
# Total score is 0.977229172179039
# CV score for class toxic is 0.9691648546412545
# CV score for class severe_toxic is 0.9831273206622969
# CV score for class obscene is 0.9816156539128406
# CV score for class threat is 0.9846641486930215
# CV score for class insult is 0.9750111635352737
# CV score for class identity_hate is 0.9714530450430018
# ITERATION:   11
# Parameters   0.8    9000     (1, 1)    1
# Total score is 0.9775060310812815
# CV score for class toxic is 0.970507178878632
# CV score for class severe_toxic is 0.9825748565010568
# CV score for class obscene is 0.9819513934087073
# CV score for class threat is 0.9869402942721252
# CV score for class insult is 0.9751588779565329
# CV score for class identity_hate is 0.9715140568106589
# ITERATION:   12
# Parameters   0.8    9000     (1, 1)    3
# Total score is 0.9781077763046189
# CV score for class toxic is 0.969787148065275
# CV score for class severe_toxic is 0.9814101030239474
# CV score for class obscene is 0.9807582844813734
# CV score for class threat is 0.9865286738509065
# CV score for class insult is 0.9738452234031234
# CV score for class identity_hate is 0.9697600348644801
# ITERATION:   13
# Parameters   0.8    9000     (1, 1)    5
# Total score is 0.9770149112815177
# CV score for class toxic is 0.9676849917652514
# CV score for class severe_toxic is 0.9785745806902427
# CV score for class obscene is 0.9779176896602378
# CV score for class threat is 0.984785391955783
# CV score for class insult is 0.970720198308749
# CV score for class identity_hate is 0.9656728024259321
# ITERATION:   14
# Parameters   0.8    9000     (1, 1)    10
# Total score is 0.9742259424676994
# CV score for class toxic is 0.9660165489184193
# CV score for class severe_toxic is 0.982274089221541
# CV score for class obscene is 0.9793109188834942
# CV score for class threat is 0.9838499646947136
# CV score for class insult is 0.9732681416536737
# CV score for class identity_hate is 0.969525650452026
# ITERATION:   15
# Parameters   0.8    9000     (1, 2)    0.9
# Total score is 0.9757075523039779
# CV score for class toxic is 0.9663322329263492
# CV score for class severe_toxic is 0.9823468257870097
# CV score for class obscene is 0.9795578477914585
# CV score for class threat is 0.9843032644872839
# CV score for class insult is 0.9734565106117894
# CV score for class identity_hate is 0.9698019613624176
# ITERATION:   16
# Parameters   0.8    9000     (1, 2)    1
# Total score is 0.9759664404943846
# CV score for class toxic is 0.9669241183203989
# CV score for class severe_toxic is 0.9816357733797657
# CV score for class obscene is 0.9795070816143339
# CV score for class threat is 0.986664627567231
# CV score for class insult is 0.9729017535285932
# CV score for class identity_hate is 0.9694806978571736
# ITERATION:   17
# Parameters   0.8    9000     (1, 2)    3
# Total score is 0.976185675377916
# CV score for class toxic is 0.9657481848844339
# CV score for class severe_toxic is 0.9801094933301816
# CV score for class obscene is 0.9779534181591986
# CV score for class threat is 0.9863283420723379
# CV score for class insult is 0.9710826298638926
# CV score for class identity_hate is 0.9674695200216776
# ITERATION:   18
# Parameters   0.8    9000     (1, 2)    5
# Total score is 0.9747819313886205
# CV score for class toxic is 0.9630030871585888
# CV score for class severe_toxic is 0.9764027933374001
# CV score for class obscene is 0.9745189126958627
# CV score for class threat is 0.9846722644219371
# CV score for class insult is 0.9671673529570696
# CV score for class identity_hate is 0.9627995320825766
# ITERATION:   19
# Parameters   0.8    9000     (1, 2)    10
# Total score is 0.9714273237755724
# CV score for class toxic is 0.9693160608986995
# CV score for class severe_toxic is 0.9828935411520613
# CV score for class obscene is 0.9816848736099733
# CV score for class threat is 0.9837234196597638
# CV score for class insult is 0.9750320030152837
# CV score for class identity_hate is 0.97144191995399
# ITERATION:   20
# Parameters   0.8    17000     (1, 1)    0.9
# Total score is 0.9773486363816285
# CV score for class toxic is 0.969761733858194
# CV score for class severe_toxic is 0.9829536050196244
# CV score for class obscene is 0.982003717422035
# CV score for class threat is 0.9842271903074215
# CV score for class insult is 0.9753241814834114
# CV score for class identity_hate is 0.9718105388247834
# ITERATION:   21
# Parameters   0.8    17000     (1, 1)    1
# Total score is 0.9776801611525783
# CV score for class toxic is 0.971785665482568
# CV score for class severe_toxic is 0.9824738479080665
# CV score for class obscene is 0.9829691474637471
# CV score for class threat is 0.9870091466466334
# CV score for class insult is 0.9760907770002181
# CV score for class identity_hate is 0.9725466924030483
# ITERATION:   22
# Parameters   0.8    17000     (1, 1)    3
# Total score is 0.9788125461507136
# CV score for class toxic is 0.97126276692366
# CV score for class severe_toxic is 0.9813697419860041
# CV score for class obscene is 0.9820720110515709
# CV score for class threat is 0.9867919975913381
# CV score for class insult is 0.974995116960495
# CV score for class identity_hate is 0.9711436557301053
# ITERATION:   23
# Parameters   0.8    17000     (1, 1)    5
# Total score is 0.9779392150405289
# CV score for class toxic is 0.9692258608107323
# CV score for class severe_toxic is 0.9786665945842206
# CV score for class obscene is 0.9795873410892545
# CV score for class threat is 0.9854358107883736
# CV score for class insult is 0.9719942263456233
# CV score for class identity_hate is 0.9675543461375241
# ITERATION:   24
# Parameters   0.8    17000     (1, 1)    10
# Total score is 0.9754106966259547
# CV score for class toxic is 0.9671707756467972
# CV score for class severe_toxic is 0.9820646856538747
# CV score for class obscene is 0.9799627397130903
# CV score for class threat is 0.9833727547941086
# CV score for class insult is 0.9740516504116523
# CV score for class identity_hate is 0.9697079019272111
# ITERATION:   25
# Parameters   0.8    17000     (1, 2)    0.9
# Total score is 0.9760550846911223
# CV score for class toxic is 0.9676008093379981
# CV score for class severe_toxic is 0.9821452459388094
# CV score for class obscene is 0.9803295798119568
# CV score for class threat is 0.9838626817333257
# CV score for class insult is 0.9743405656421533
# CV score for class identity_hate is 0.9700603839092573
# ITERATION:   26
# Parameters   0.8    17000     (1, 2)    1
# Total score is 0.9763898777289168
# CV score for class toxic is 0.969155306368979
# CV score for class severe_toxic is 0.9815975153828153
# CV score for class obscene is 0.9814722266421776
# CV score for class threat is 0.9866229032279169
# CV score for class insult is 0.9747832622677324
# CV score for class identity_hate is 0.9703553843228039
# ITERATION:   27
# Parameters   0.8    17000     (1, 2)    3
# Total score is 0.977331099702071
# CV score for class toxic is 0.9682028412778513
# CV score for class severe_toxic is 0.9801909525000397
# CV score for class obscene is 0.9804160250882775
# CV score for class threat is 0.986462169446438
# CV score for class insult is 0.9733109197301203
# CV score for class identity_hate is 0.9685680100527878
# ITERATION:   28
# Parameters   0.8    17000     (1, 2)    5
# Total score is 0.9761918196825858
# CV score for class toxic is 0.9654839229791699
# CV score for class severe_toxic is 0.9766524269556629
# CV score for class obscene is 0.9775516188669539
# CV score for class threat is 0.9850733502331831
# CV score for class insult is 0.969634972334584
# CV score for class identity_hate is 0.9643237603010549
# ITERATION:   29
# Parameters   0.8    17000     (1, 2)    10
# Total score is 0.9731200086117681
# CV score for class toxic is 0.9693060738252862
# CV score for class severe_toxic is 0.9830009811088223
# CV score for class obscene is 0.9818472658073484
# CV score for class threat is 0.983235044362328
# CV score for class insult is 0.9749804929944555
# CV score for class identity_hate is 0.9715988422106107
# ITERATION:   30
# Parameters   0.8    25000     (1, 1)    0.9
# Total score is 0.9773281167181419
# CV score for class toxic is 0.9697882703306213
# CV score for class severe_toxic is 0.9830739662680367
# CV score for class obscene is 0.9822041507831946
# CV score for class threat is 0.9837411409901974
# CV score for class insult is 0.9753012914668594
# CV score for class identity_hate is 0.9720031059967389
# ITERATION:   31
# Parameters   0.8    25000     (1, 1)    1
# Total score is 0.9776853209726081
# CV score for class toxic is 0.9721749088070916
# CV score for class severe_toxic is 0.9827515204871831
# CV score for class obscene is 0.983592162351766
# CV score for class threat is 0.9866172125569763
# CV score for class insult is 0.9763877438244065
# CV score for class identity_hate is 0.9732951671843547
# ITERATION:   32
# Parameters   0.8    25000     (1, 1)    3
# Total score is 0.9791364525352964
# CV score for class toxic is 0.9718243400335931
# CV score for class severe_toxic is 0.9817398141018273
# CV score for class obscene is 0.9829043984300911
# CV score for class threat is 0.986438348286021
# CV score for class insult is 0.9754367430575056
# CV score for class identity_hate is 0.9722026662496797
# ITERATION:   33
# Parameters   0.8    25000     (1, 1)    5
# Total score is 0.978424385026453
# CV score for class toxic is 0.9700381864748772
# CV score for class severe_toxic is 0.979191802280286
# CV score for class obscene is 0.9807396234911958
# CV score for class threat is 0.9851412503740248
# CV score for class insult is 0.972590536107707
# CV score for class identity_hate is 0.9691532289442009
# ITERATION:   34
# Parameters   0.8    25000     (1, 1)    10
# Total score is 0.9761424379453819
# CV score for class toxic is 0.9671601450503825
# CV score for class severe_toxic is 0.9824264614282431
# CV score for class obscene is 0.9797058374251183
# CV score for class threat is 0.9832867792618986
# CV score for class insult is 0.9739477832515441
# CV score for class identity_hate is 0.9691552868756075
# ITERATION:   35
# Parameters   0.8    25000     (1, 2)    0.9
# Total score is 0.9759470488821324
# CV score for class toxic is 0.9676516397183028
# CV score for class severe_toxic is 0.9825045584164428
# CV score for class obscene is 0.9801209906606404
# CV score for class threat is 0.983799336204681
# CV score for class insult is 0.9742883954688463
# CV score for class identity_hate is 0.9695713707150491
# ITERATION:   36
# Parameters   0.8    25000     (1, 2)    1
# Total score is 0.9763227151973272
# CV score for class toxic is 0.9697413602738402
# CV score for class severe_toxic is 0.9821004172471116
# CV score for class obscene is 0.9816415345196495
# CV score for class threat is 0.9869626245716332
# CV score for class insult is 0.9752267673795334
# CV score for class identity_hate is 0.9704467229943016
# ITERATION:   37
# Parameters   0.8    25000     (1, 2)    3
# Total score is 0.9776865711643449
# CV score for class toxic is 0.9689875236461022
# CV score for class severe_toxic is 0.9808922254964411
# CV score for class obscene is 0.9807353345129638
# CV score for class threat is 0.986973947850486
# CV score for class insult is 0.9739994621136905
# CV score for class identity_hate is 0.9690131074600131
# ITERATION:   38
# Parameters   0.8    25000     (1, 2)    5
# Total score is 0.9767669335132827
# CV score for class toxic is 0.9665178918581129
# CV score for class severe_toxic is 0.9778547329674087
# CV score for class obscene is 0.9781589144254558
# CV score for class threat is 0.9858946122381961
# CV score for class insult is 0.9706672580007414
# CV score for class identity_hate is 0.9654556559884959
# ITERATION:   39
# Parameters   0.8    25000     (1, 2)    10
# Total score is 0.9740915109130684
# CV score for class toxic is 0.9692539474373367
# CV score for class severe_toxic is 0.9829949171669577
# CV score for class obscene is 0.9819058553696567
# CV score for class threat is 0.9827996116754542
# CV score for class insult is 0.9749071837508723
# CV score for class identity_hate is 0.9717737230430181
# ITERATION:   40
# Parameters   0.8    33000     (1, 1)    0.9
# Total score is 0.9772725397405493
# CV score for class toxic is 0.9697530516896403
# CV score for class severe_toxic is 0.983067090711506
# CV score for class obscene is 0.9822907525708624
# CV score for class threat is 0.9833277801605855
# CV score for class insult is 0.9752448783593701
# CV score for class identity_hate is 0.9721937016955536
# ITERATION:   41
# Parameters   0.8    33000     (1, 1)    1
# Total score is 0.9776462091979198
# CV score for class toxic is 0.9723486092939314
# CV score for class severe_toxic is 0.9827776849370092
# CV score for class obscene is 0.9839356585724762
# CV score for class threat is 0.9864528101804068
# CV score for class insult is 0.9764931747512243
# CV score for class identity_hate is 0.9736464986651194
# ITERATION:   42
# Parameters   0.8    33000     (1, 1)    3
# Total score is 0.9792757394000279
# CV score for class toxic is 0.9720965634583667
# CV score for class severe_toxic is 0.9818063570994436
# CV score for class obscene is 0.9833762905383386
# CV score for class threat is 0.9863854190176017
# CV score for class insult is 0.9756123658913628
# CV score for class identity_hate is 0.9726729411450297
# ITERATION:   43
# Parameters   0.8    33000     (1, 1)    5
# Total score is 0.9786583228583572
# CV score for class toxic is 0.9704388740720686
# CV score for class severe_toxic is 0.9793454925256398
# CV score for class obscene is 0.9814088056067943
# CV score for class threat is 0.985275127163468
# CV score for class insult is 0.9728393507437962
# CV score for class identity_hate is 0.9698659551697126
# ITERATION:   44
# Parameters   0.8    33000     (1, 1)    10
# Total score is 0.9765289342135799
# CV score for class toxic is 0.9672008346239268
# CV score for class severe_toxic is 0.9822811467155432
# CV score for class obscene is 0.9795722999643143
# CV score for class threat is 0.9828360448668785
# CV score for class insult is 0.9738390040853604
# CV score for class identity_hate is 0.9687821930298236
# ITERATION:   45
# Parameters   0.8    33000     (1, 2)    0.9
# Total score is 0.975751920547641
# CV score for class toxic is 0.9677360015430209
# CV score for class severe_toxic is 0.9823609388153655
# CV score for class obscene is 0.9800143393644823
# CV score for class threat is 0.9833698244642477
# CV score for class insult is 0.9742074564722278
# CV score for class identity_hate is 0.9692336571528865
# ITERATION:   46
# Parameters   0.8    33000     (1, 2)    1
# Total score is 0.9761537029687051
# CV score for class toxic is 0.9702864604240272
# CV score for class severe_toxic is 0.9820699021594375
# CV score for class obscene is 0.9818561032793057
# CV score for class threat is 0.9867236924917577
# CV score for class insult is 0.9754552918804035
# CV score for class identity_hate is 0.9704699845453627
# ITERATION:   47
# Parameters   0.8    33000     (1, 2)    3
# Total score is 0.977810239130049
# CV score for class toxic is 0.9697459056373239
# CV score for class severe_toxic is 0.9809961837223353
# CV score for class obscene is 0.9811049668920164
# CV score for class threat is 0.9867702187670618
# CV score for class insult is 0.9743795142563267
# CV score for class identity_hate is 0.9691938148565334
# ITERATION:   48
# Parameters   0.8    33000     (1, 2)    5
# Total score is 0.9770317673552662
# CV score for class toxic is 0.9676075013744603
# CV score for class severe_toxic is 0.9782550106260134
# CV score for class obscene is 0.9787945351673636
# CV score for class threat is 0.9857422113660667
# CV score for class insult is 0.9712878080603592
# CV score for class identity_hate is 0.9659602209550912
# ITERATION:   49
# Parameters   0.8    33000     (1, 2)    10
# Total score is 0.9746078812582257
# CV score for class toxic is 0.9488783969088379
# CV score for class severe_toxic is 0.9787903595638028
# CV score for class obscene is 0.9708751938217719
# CV score for class threat is 0.9806301963198457
# CV score for class insult is 0.9597272327776771
# CV score for class identity_hate is 0.9570001310598428
# ITERATION:   50
# Parameters   0.9    1000     (1, 1)    0.9
# Total score is 0.9659835850752964
# CV score for class toxic is 0.9489345006635187
# CV score for class severe_toxic is 0.9787558968210993
# CV score for class obscene is 0.9708815563509644
# CV score for class threat is 0.9808318267336373
# CV score for class insult is 0.9596572687514041
# CV score for class identity_hate is 0.9569165006691582
# ITERATION:   51
# Parameters   0.9    1000     (1, 1)    1
# Total score is 0.9659962583316304
# CV score for class toxic is 0.9488103271385269
# CV score for class severe_toxic is 0.9773974603011654
# CV score for class obscene is 0.9699542675884641
# CV score for class threat is 0.9803719702662345
# CV score for class insult is 0.9582429903589081
# CV score for class identity_hate is 0.9542483593811397
# ITERATION:   52
# Parameters   0.9    1000     (1, 1)    3
# Total score is 0.9648375625057398
# CV score for class toxic is 0.9485350809687626
# CV score for class severe_toxic is 0.9762759347006412
# CV score for class obscene is 0.9691589325346758
# CV score for class threat is 0.9786725790790776
# CV score for class insult is 0.9574100329748524
# CV score for class identity_hate is 0.9521419661217995
# ITERATION:   53
# Parameters   0.9    1000     (1, 1)    5
# Total score is 0.9636990877299682
# CV score for class toxic is 0.9481502868670937
# CV score for class severe_toxic is 0.9743995224211542
# CV score for class obscene is 0.9680307825319185
# CV score for class threat is 0.9750407102129298
# CV score for class insult is 0.9563380454360305
# CV score for class identity_hate is 0.9487515773107275
# ITERATION:   54
# Parameters   0.9    1000     (1, 1)    10
# Total score is 0.9617851541299758
# CV score for class toxic is 0.9375349835375028
# CV score for class severe_toxic is 0.975938147438554
# CV score for class obscene is 0.9581609184066527
# CV score for class threat is 0.9676506191772171
# CV score for class insult is 0.9489283485971217
# CV score for class identity_hate is 0.9444568967391295
# ITERATION:   55
# Parameters   0.9    1000     (1, 2)    0.9
# Total score is 0.955444985649363
# CV score for class toxic is 0.9375892742131202
# CV score for class severe_toxic is 0.9758660637131604
# CV score for class obscene is 0.9581319001759256
# CV score for class threat is 0.9679022169037476
# CV score for class insult is 0.9488287236971663
# CV score for class identity_hate is 0.9443186288723454
# ITERATION:   56
# Parameters   0.9    1000     (1, 2)    1
# Total score is 0.9554394679292443
# CV score for class toxic is 0.9375279852089894
# CV score for class severe_toxic is 0.9740825844256955
# CV score for class obscene is 0.9568955728062895
# CV score for class threat is 0.9674444872727226
# CV score for class insult is 0.9470256871001214
# CV score for class identity_hate is 0.9410965396380587
# ITERATION:   57
# Parameters   0.9    1000     (1, 2)    3
# Total score is 0.9540121427419795
# CV score for class toxic is 0.9373069107626835
# CV score for class severe_toxic is 0.9726845909098771
# CV score for class obscene is 0.9559965627832999
# CV score for class threat is 0.9654196794954433
# CV score for class insult is 0.9459969857569231
# CV score for class identity_hate is 0.9387979961882243
# ITERATION:   58
# Parameters   0.9    1000     (1, 2)    5
# Total score is 0.9527004543160752
# CV score for class toxic is 0.9369811497508582
# CV score for class severe_toxic is 0.970371770927453
# CV score for class obscene is 0.9547933429389818
# CV score for class threat is 0.9611372771531085
# CV score for class insult is 0.9446985012530099
# CV score for class identity_hate is 0.9351982082801357
# ITERATION:   59
# Parameters   0.9    1000     (1, 2)    10
# Total score is 0.9505300417172579
# CV score for class toxic is 0.9687992076438979
# CV score for class severe_toxic is 0.9830693770362776
# CV score for class obscene is 0.9813601732132998
# CV score for class threat is 0.984210289024611
# CV score for class insult is 0.9747840298708232
# CV score for class identity_hate is 0.9711519562853255
# ITERATION:   60
# Parameters   0.9    9000     (1, 1)    0.9
# Total score is 0.977229172179039
# CV score for class toxic is 0.9691648546412545
# CV score for class severe_toxic is 0.9831273206622969
# CV score for class obscene is 0.9816156539128406
# CV score for class threat is 0.9846641486930215
# CV score for class insult is 0.9750111635352737
# CV score for class identity_hate is 0.9714530450430018
# ITERATION:   61
# Parameters   0.9    9000     (1, 1)    1
# Total score is 0.9775060310812815
# CV score for class toxic is 0.970507178878632
# CV score for class severe_toxic is 0.9825748565010568
# CV score for class obscene is 0.9819513934087073
# CV score for class threat is 0.9869402942721252
# CV score for class insult is 0.9751588779565329
# CV score for class identity_hate is 0.9715140568106589
# ITERATION:   62
# Parameters   0.9    9000     (1, 1)    3
# Total score is 0.9781077763046189
# CV score for class toxic is 0.969787148065275
# CV score for class severe_toxic is 0.9814101030239474
# CV score for class obscene is 0.9807582844813734
# CV score for class threat is 0.9865286738509065
# CV score for class insult is 0.9738452234031234
# CV score for class identity_hate is 0.9697600348644801
# ITERATION:   63
# Parameters   0.9    9000     (1, 1)    5
# Total score is 0.9770149112815177
# CV score for class toxic is 0.9676849917652514
# CV score for class severe_toxic is 0.9785745806902427
# CV score for class obscene is 0.9779176896602378
# CV score for class threat is 0.984785391955783
# CV score for class insult is 0.970720198308749
# CV score for class identity_hate is 0.9656728024259321
# ITERATION:   64
# Parameters   0.9    9000     (1, 1)    10
# Total score is 0.9742259424676994
# CV score for class toxic is 0.9660165489184193
# CV score for class severe_toxic is 0.982274089221541
# CV score for class obscene is 0.9793109188834942
# CV score for class threat is 0.9838499646947136
# CV score for class insult is 0.9732681416536737
# CV score for class identity_hate is 0.969525650452026
# ITERATION:   65
# Parameters   0.9    9000     (1, 2)    0.9
# Total score is 0.9757075523039779
# CV score for class toxic is 0.9663322329263492
# CV score for class severe_toxic is 0.9823468257870097
# CV score for class obscene is 0.9795578477914585
# CV score for class threat is 0.9843032644872839
# CV score for class insult is 0.9734565106117894
# CV score for class identity_hate is 0.9698019613624176
# ITERATION:   66
# Parameters   0.9    9000     (1, 2)    1
# Total score is 0.9759664404943846
# CV score for class toxic is 0.9669241183203989
# CV score for class severe_toxic is 0.9816357733797657
# CV score for class obscene is 0.9795070816143339
# CV score for class threat is 0.986664627567231
# CV score for class insult is 0.9729017535285932
# CV score for class identity_hate is 0.9694806978571736
# ITERATION:   67
# Parameters   0.9    9000     (1, 2)    3
# Total score is 0.976185675377916
# CV score for class toxic is 0.9657481848844339
# CV score for class severe_toxic is 0.9801094933301816
# CV score for class obscene is 0.9779534181591986
# CV score for class threat is 0.9863283420723379
# CV score for class insult is 0.9710826298638926
# CV score for class identity_hate is 0.9674695200216776
# ITERATION:   68
# Parameters   0.9    9000     (1, 2)    5
# Total score is 0.9747819313886205
# CV score for class toxic is 0.9630030871585888
# CV score for class severe_toxic is 0.9764027933374001
# CV score for class obscene is 0.9745189126958627
# CV score for class threat is 0.9846722644219371
# CV score for class insult is 0.9671673529570696
# CV score for class identity_hate is 0.9627995320825766
# ITERATION:   69
# Parameters   0.9    9000     (1, 2)    10
# Total score is 0.9714273237755724
# CV score for class toxic is 0.9693160608986995
# CV score for class severe_toxic is 0.9828935411520613
# CV score for class obscene is 0.9816848736099733
# CV score for class threat is 0.9837234196597638
# CV score for class insult is 0.9750320030152837
# CV score for class identity_hate is 0.97144191995399
# ITERATION:   70
# Parameters   0.9    17000     (1, 1)    0.9
# Total score is 0.9773486363816285
# CV score for class toxic is 0.969761733858194
# CV score for class severe_toxic is 0.9829536050196244
# CV score for class obscene is 0.982003717422035
# CV score for class threat is 0.9842271903074215
# CV score for class insult is 0.9753241814834114
# CV score for class identity_hate is 0.9718105388247834
# ITERATION:   71
# Parameters   0.9    17000     (1, 1)    1
# Total score is 0.9776801611525783
# CV score for class toxic is 0.971785665482568
# CV score for class severe_toxic is 0.9824738479080665
# CV score for class obscene is 0.9829691474637471
# CV score for class threat is 0.9870091466466334
# CV score for class insult is 0.9760907770002181
# CV score for class identity_hate is 0.9725466924030483
# ITERATION:   72
# Parameters   0.9    17000     (1, 1)    3
# Total score is 0.9788125461507136
# CV score for class toxic is 0.97126276692366
# CV score for class severe_toxic is 0.9813697419860041
# CV score for class obscene is 0.9820720110515709
# CV score for class threat is 0.9867919975913381
# CV score for class insult is 0.974995116960495
# CV score for class identity_hate is 0.9711436557301053
# ITERATION:   73
# Parameters   0.9    17000     (1, 1)    5
# Total score is 0.9779392150405289
# CV score for class toxic is 0.9692258608107323
# CV score for class severe_toxic is 0.9786665945842206
# CV score for class obscene is 0.9795873410892545
# CV score for class threat is 0.9854358107883736
# CV score for class insult is 0.9719942263456233
# CV score for class identity_hate is 0.9675543461375241
# ITERATION:   74
# Parameters   0.9    17000     (1, 1)    10
# Total score is 0.9754106966259547
# CV score for class toxic is 0.9671707756467972
# CV score for class severe_toxic is 0.9820646856538747
# CV score for class obscene is 0.9799627397130903
# CV score for class threat is 0.9833727547941086
# CV score for class insult is 0.9740516504116523
# CV score for class identity_hate is 0.9697079019272111
# ITERATION:   75
# Parameters   0.9    17000     (1, 2)    0.9
# Total score is 0.9760550846911223
# CV score for class toxic is 0.9676008093379981
# CV score for class severe_toxic is 0.9821452459388094
# CV score for class obscene is 0.9803295798119568
# CV score for class threat is 0.9838626817333257
# CV score for class insult is 0.9743405656421533
# CV score for class identity_hate is 0.9700603839092573
# ITERATION:   76
# Parameters   0.9    17000     (1, 2)    1
# Total score is 0.9763898777289168
# CV score for class toxic is 0.969155306368979
# CV score for class severe_toxic is 0.9815975153828153
# CV score for class obscene is 0.9814722266421776
# CV score for class threat is 0.9866229032279169
# CV score for class insult is 0.9747832622677324
# CV score for class identity_hate is 0.9703553843228039
# ITERATION:   77
# Parameters   0.9    17000     (1, 2)    3
# Total score is 0.977331099702071
# CV score for class toxic is 0.9682028412778513
# CV score for class severe_toxic is 0.9801909525000397
# CV score for class obscene is 0.9804160250882775
# CV score for class threat is 0.986462169446438
# CV score for class insult is 0.9733109197301203
# CV score for class identity_hate is 0.9685680100527878
# ITERATION:   78
# Parameters   0.9    17000     (1, 2)    5
# Total score is 0.9761918196825858
# CV score for class toxic is 0.9654839229791699
# CV score for class severe_toxic is 0.9766524269556629
# CV score for class obscene is 0.9775516188669539
# CV score for class threat is 0.9850733502331831
# CV score for class insult is 0.969634972334584
# CV score for class identity_hate is 0.9643237603010549
# ITERATION:   79
# Parameters   0.9    17000     (1, 2)    10
# Total score is 0.9731200086117681
# CV score for class toxic is 0.9693060738252862
# CV score for class severe_toxic is 0.9830009811088223
# CV score for class obscene is 0.9818472658073484
# CV score for class threat is 0.983235044362328
# CV score for class insult is 0.9749804929944555
# CV score for class identity_hate is 0.9715988422106107
# ITERATION:   80
# Parameters   0.9    25000     (1, 1)    0.9
# Total score is 0.9773281167181419
# CV score for class toxic is 0.9697882703306213
# CV score for class severe_toxic is 0.9830739662680367
# CV score for class obscene is 0.9822041507831946
# CV score for class threat is 0.9837411409901974
# CV score for class insult is 0.9753012914668594
# CV score for class identity_hate is 0.9720031059967389
# ITERATION:   81
# Parameters   0.9    25000     (1, 1)    1
# Total score is 0.9776853209726081
# CV score for class toxic is 0.9721749088070916
# CV score for class severe_toxic is 0.9827515204871831
# CV score for class obscene is 0.983592162351766
# CV score for class threat is 0.9866172125569763
# CV score for class insult is 0.9763877438244065
# CV score for class identity_hate is 0.9732951671843547
# ITERATION:   82
# Parameters   0.9    25000     (1, 1)    3
# Total score is 0.9791364525352964
# CV score for class toxic is 0.9718243400335931
# CV score for class severe_toxic is 0.9817398141018273
# CV score for class obscene is 0.9829043984300911
# CV score for class threat is 0.986438348286021
# CV score for class insult is 0.9754367430575056
# CV score for class identity_hate is 0.9722026662496797
# ITERATION:   83
# Parameters   0.9    25000     (1, 1)    5
# Total score is 0.978424385026453
# CV score for class toxic is 0.9700381864748772
# CV score for class severe_toxic is 0.979191802280286
# CV score for class obscene is 0.9807396234911958
# CV score for class threat is 0.9851412503740248
# CV score for class insult is 0.972590536107707
# CV score for class identity_hate is 0.9691532289442009
# ITERATION:   84
# Parameters   0.9    25000     (1, 1)    10
# Total score is 0.9761424379453819
# CV score for class toxic is 0.9671601450503825
# CV score for class severe_toxic is 0.9824264614282431
# CV score for class obscene is 0.9797058374251183
# CV score for class threat is 0.9832867792618986
# CV score for class insult is 0.9739477832515441
# CV score for class identity_hate is 0.9691552868756075
# ITERATION:   85
# Parameters   0.9    25000     (1, 2)    0.9
# Total score is 0.9759470488821324
# CV score for class toxic is 0.9676516397183028
# CV score for class severe_toxic is 0.9825045584164428
# CV score for class obscene is 0.9801209906606404
# CV score for class threat is 0.983799336204681
# CV score for class insult is 0.9742883954688463
# CV score for class identity_hate is 0.9695713707150491
# ITERATION:   86
# Parameters   0.9    25000     (1, 2)    1
# Total score is 0.9763227151973272
# CV score for class toxic is 0.9697413602738402
# CV score for class severe_toxic is 0.9821004172471116
# CV score for class obscene is 0.9816415345196495
# CV score for class threat is 0.9869626245716332
# CV score for class insult is 0.9752267673795334
# CV score for class identity_hate is 0.9704467229943016
# ITERATION:   87
# Parameters   0.9    25000     (1, 2)    3
# Total score is 0.9776865711643449
# CV score for class toxic is 0.9689875236461022
# CV score for class severe_toxic is 0.9808922254964411
# CV score for class obscene is 0.9807353345129638
# CV score for class threat is 0.986973947850486
# CV score for class insult is 0.9739994621136905
# CV score for class identity_hate is 0.9690131074600131
# ITERATION:   88
# Parameters   0.9    25000     (1, 2)    5
# Total score is 0.9767669335132827
# CV score for class toxic is 0.9665178918581129
# CV score for class severe_toxic is 0.9778547329674087
# CV score for class obscene is 0.9781589144254558
# CV score for class threat is 0.9858946122381961
# CV score for class insult is 0.9706672580007414
# CV score for class identity_hate is 0.9654556559884959
# ITERATION:   89
# Parameters   0.9    25000     (1, 2)    10
# Total score is 0.9740915109130684
# CV score for class toxic is 0.9692539474373367
# CV score for class severe_toxic is 0.9829949171669577
# CV score for class obscene is 0.9819058553696567
# CV score for class threat is 0.9827996116754542
# CV score for class insult is 0.9749071837508723
# CV score for class identity_hate is 0.9717737230430181
# ITERATION:   90
# Parameters   0.9    33000     (1, 1)    0.9
# Total score is 0.9772725397405493
# CV score for class toxic is 0.9697530516896403
# CV score for class severe_toxic is 0.983067090711506
# CV score for class obscene is 0.9822907525708624
# CV score for class threat is 0.9833277801605855
# CV score for class insult is 0.9752448783593701
# CV score for class identity_hate is 0.9721937016955536
# ITERATION:   91
# Parameters   0.9    33000     (1, 1)    1
# Total score is 0.9776462091979198
# CV score for class toxic is 0.9723486092939314
# CV score for class severe_toxic is 0.9827776849370092
# CV score for class obscene is 0.9839356585724762
# CV score for class threat is 0.9864528101804068
# CV score for class insult is 0.9764931747512243
# CV score for class identity_hate is 0.9736464986651194
# ITERATION:   92
# Parameters   0.9    33000     (1, 1)    3
# Total score is 0.9792757394000279
# CV score for class toxic is 0.9720965634583667
# CV score for class severe_toxic is 0.9818063570994436
# CV score for class obscene is 0.9833762905383386
# CV score for class threat is 0.9863854190176017
# CV score for class insult is 0.9756123658913628
# CV score for class identity_hate is 0.9726729411450297
# ITERATION:   93
# Parameters   0.9    33000     (1, 1)    5
# Total score is 0.9786583228583572
# CV score for class toxic is 0.9704388740720686
# CV score for class severe_toxic is 0.9793454925256398
# CV score for class obscene is 0.9814088056067943
# CV score for class threat is 0.985275127163468
# CV score for class insult is 0.9728393507437962
# CV score for class identity_hate is 0.9698659551697126
# ITERATION:   94
# Parameters   0.9    33000     (1, 1)    10
# Total score is 0.9765289342135799
# CV score for class toxic is 0.9672008346239268
# CV score for class severe_toxic is 0.9822811467155432
# CV score for class obscene is 0.9795722999643143
# CV score for class threat is 0.9828360448668785
# CV score for class insult is 0.9738390040853604
# CV score for class identity_hate is 0.9687821930298236
# ITERATION:   95
# Parameters   0.9    33000     (1, 2)    0.9
# Total score is 0.975751920547641
# CV score for class toxic is 0.9677360015430209
# CV score for class severe_toxic is 0.9823609388153655
# CV score for class obscene is 0.9800143393644823
# CV score for class threat is 0.9833698244642477
# CV score for class insult is 0.9742074564722278
# CV score for class identity_hate is 0.9692336571528865
# ITERATION:   96
# Parameters   0.9    33000     (1, 2)    1
# Total score is 0.9761537029687051
# CV score for class toxic is 0.9702864604240272
# CV score for class severe_toxic is 0.9820699021594375
# CV score for class obscene is 0.9818561032793057
# CV score for class threat is 0.9867236924917577
# CV score for class insult is 0.9754552918804035
# CV score for class identity_hate is 0.9704699845453627
# ITERATION:   97
# Parameters   0.9    33000     (1, 2)    3
# Total score is 0.977810239130049
# CV score for class toxic is 0.9697459056373239
# CV score for class severe_toxic is 0.9809961837223353
# CV score for class obscene is 0.9811049668920164
# CV score for class threat is 0.9867702187670618
# CV score for class insult is 0.9743795142563267
# CV score for class identity_hate is 0.9691938148565334
# ITERATION:   98
# Parameters   0.9    33000     (1, 2)    5
# Total score is 0.9770317673552662
# CV score for class toxic is 0.9676075013744603
# CV score for class severe_toxic is 0.9782550106260134
# CV score for class obscene is 0.9787945351673636
# CV score for class threat is 0.9857422113660667
# CV score for class insult is 0.9712878080603592
# CV score for class identity_hate is 0.9659602209550912
# ITERATION:   99
# Parameters   0.9    33000     (1, 2)    10
# Total score is 0.9746078812582257
# CV score for class toxic is 0.9488783969088379
# CV score for class severe_toxic is 0.9787903595638028
# CV score for class obscene is 0.9708751938217719
# CV score for class threat is 0.9806301963198457
# CV score for class insult is 0.9597272327776771
# CV score for class identity_hate is 0.9570001310598428
# ITERATION:   100
# Parameters   1.0    1000     (1, 1)    0.9
# Total score is 0.9659835850752964
# CV score for class toxic is 0.9489345006635187
# CV score for class severe_toxic is 0.9787558968210993
# CV score for class obscene is 0.9708815563509644
# CV score for class threat is 0.9808318267336373
# CV score for class insult is 0.9596572687514041
# CV score for class identity_hate is 0.9569165006691582
# ITERATION:   101
# Parameters   1.0    1000     (1, 1)    1
# Total score is 0.9659962583316304
# CV score for class toxic is 0.9488103271385269
# CV score for class severe_toxic is 0.9773974603011654
# CV score for class obscene is 0.9699542675884641
# CV score for class threat is 0.9803719702662345
# CV score for class insult is 0.9582429903589081
# CV score for class identity_hate is 0.9542483593811397
# ITERATION:   102
# Parameters   1.0    1000     (1, 1)    3
# Total score is 0.9648375625057398
# CV score for class toxic is 0.9485350809687626
# CV score for class severe_toxic is 0.9762759347006412
# CV score for class obscene is 0.9691589325346758
# CV score for class threat is 0.9786725790790776
# CV score for class insult is 0.9574100329748524
# CV score for class identity_hate is 0.9521419661217995
# ITERATION:   103
# Parameters   1.0    1000     (1, 1)    5
# Total score is 0.9636990877299682
# CV score for class toxic is 0.9481502868670937
# CV score for class severe_toxic is 0.9743995224211542
# CV score for class obscene is 0.9680307825319185
# CV score for class threat is 0.9750407102129298
# CV score for class insult is 0.9563380454360305
# CV score for class identity_hate is 0.9487515773107275
# ITERATION:   104
# Parameters   1.0    1000     (1, 1)    10
# Total score is 0.9617851541299758
# CV score for class toxic is 0.9375349835375028
# CV score for class severe_toxic is 0.975938147438554
# CV score for class obscene is 0.9581609184066527
# CV score for class threat is 0.9676506191772171
# CV score for class insult is 0.9489283485971217
# CV score for class identity_hate is 0.9444568967391295
# ITERATION:   105
# Parameters   1.0    1000     (1, 2)    0.9
# Total score is 0.955444985649363
# CV score for class toxic is 0.9375892742131202
# CV score for class severe_toxic is 0.9758660637131604
# CV score for class obscene is 0.9581319001759256
# CV score for class threat is 0.9679022169037476
# CV score for class insult is 0.9488287236971663
# CV score for class identity_hate is 0.9443186288723454
# ITERATION:   106
# Parameters   1.0    1000     (1, 2)    1
# Total score is 0.9554394679292443
# CV score for class toxic is 0.9375279852089894
# CV score for class severe_toxic is 0.9740825844256955
# CV score for class obscene is 0.9568955728062895
# CV score for class threat is 0.9674444872727226
# CV score for class insult is 0.9470256871001214
# CV score for class identity_hate is 0.9410965396380587
# ITERATION:   107
# Parameters   1.0    1000     (1, 2)    3
# Total score is 0.9540121427419795
# CV score for class toxic is 0.9373069107626835
# CV score for class severe_toxic is 0.9726845909098771
# CV score for class obscene is 0.9559965627832999
# CV score for class threat is 0.9654196794954433
# CV score for class insult is 0.9459969857569231
# CV score for class identity_hate is 0.9387979961882243
# ITERATION:   108
# Parameters   1.0    1000     (1, 2)    5
# Total score is 0.9527004543160752
# CV score for class toxic is 0.9369811497508582
# CV score for class severe_toxic is 0.970371770927453
# CV score for class obscene is 0.9547933429389818
# CV score for class threat is 0.9611372771531085
# CV score for class insult is 0.9446985012530099
# CV score for class identity_hate is 0.9351982082801357
# ITERATION:   109
# Parameters   1.0    1000     (1, 2)    10
# Total score is 0.9505300417172579
# CV score for class toxic is 0.9687992076438979
# CV score for class severe_toxic is 0.9830693770362776
# CV score for class obscene is 0.9813601732132998
# CV score for class threat is 0.984210289024611
# CV score for class insult is 0.9747840298708232
# CV score for class identity_hate is 0.9711519562853255
# ITERATION:   110
# Parameters   1.0    9000     (1, 1)    0.9
# Total score is 0.977229172179039
# CV score for class toxic is 0.9691648546412545
# CV score for class severe_toxic is 0.9831273206622969
# CV score for class obscene is 0.9816156539128406
# CV score for class threat is 0.9846641486930215
# CV score for class insult is 0.9750111635352737
# CV score for class identity_hate is 0.9714530450430018
# ITERATION:   111
# Parameters   1.0    9000     (1, 1)    1
# Total score is 0.9775060310812815
# CV score for class toxic is 0.970507178878632
# CV score for class severe_toxic is 0.9825748565010568
# CV score for class obscene is 0.9819513934087073
# CV score for class threat is 0.9869402942721252
# CV score for class insult is 0.9751588779565329
# CV score for class identity_hate is 0.9715140568106589
# ITERATION:   112
# Parameters   1.0    9000     (1, 1)    3
# Total score is 0.9781077763046189
# CV score for class toxic is 0.969787148065275
# CV score for class severe_toxic is 0.9814101030239474
# CV score for class obscene is 0.9807582844813734
# CV score for class threat is 0.9865286738509065
# CV score for class insult is 0.9738452234031234
# CV score for class identity_hate is 0.9697600348644801
# ITERATION:   113
# Parameters   1.0    9000     (1, 1)    5
# Total score is 0.9770149112815177
# CV score for class toxic is 0.9676849917652514
# CV score for class severe_toxic is 0.9785745806902427
# CV score for class obscene is 0.9779176896602378
# CV score for class threat is 0.984785391955783
# CV score for class insult is 0.970720198308749
# CV score for class identity_hate is 0.9656728024259321
# ITERATION:   114
# Parameters   1.0    9000     (1, 1)    10
# Total score is 0.9742259424676994
# CV score for class toxic is 0.9660165489184193
# CV score for class severe_toxic is 0.982274089221541
# CV score for class obscene is 0.9793109188834942
# CV score for class threat is 0.9838499646947136
# CV score for class insult is 0.9732681416536737
# CV score for class identity_hate is 0.969525650452026
# ITERATION:   115
# Parameters   1.0    9000     (1, 2)    0.9
# Total score is 0.9757075523039779
# CV score for class toxic is 0.9663322329263492
# CV score for class severe_toxic is 0.9823468257870097
# CV score for class obscene is 0.9795578477914585
# CV score for class threat is 0.9843032644872839
# CV score for class insult is 0.9734565106117894
# CV score for class identity_hate is 0.9698019613624176
# ITERATION:   116
# Parameters   1.0    9000     (1, 2)    1
# Total score is 0.9759664404943846
# CV score for class toxic is 0.9669241183203989
# CV score for class severe_toxic is 0.9816357733797657
# CV score for class obscene is 0.9795070816143339
# CV score for class threat is 0.986664627567231
# CV score for class insult is 0.9729017535285932
# CV score for class identity_hate is 0.9694806978571736
# ITERATION:   117
# Parameters   1.0    9000     (1, 2)    3
# Total score is 0.976185675377916
# CV score for class toxic is 0.9657481848844339
# CV score for class severe_toxic is 0.9801094933301816
# CV score for class obscene is 0.9779534181591986
# CV score for class threat is 0.9863283420723379
# CV score for class insult is 0.9710826298638926
# CV score for class identity_hate is 0.9674695200216776
# ITERATION:   118
# Parameters   1.0    9000     (1, 2)    5
# Total score is 0.9747819313886205
# CV score for class toxic is 0.9630030871585888
# CV score for class severe_toxic is 0.9764027933374001
# CV score for class obscene is 0.9745189126958627
# CV score for class threat is 0.9846722644219371
# CV score for class insult is 0.9671673529570696
# CV score for class identity_hate is 0.9627995320825766
# ITERATION:   119
# Parameters   1.0    9000     (1, 2)    10
# Total score is 0.9714273237755724
# CV score for class toxic is 0.9693160608986995
# CV score for class severe_toxic is 0.9828935411520613
# CV score for class obscene is 0.9816848736099733
# CV score for class threat is 0.9837234196597638
# CV score for class insult is 0.9750320030152837
# CV score for class identity_hate is 0.97144191995399
# ITERATION:   120
# Parameters   1.0    17000     (1, 1)    0.9
# Total score is 0.9773486363816285
# CV score for class toxic is 0.969761733858194
# CV score for class severe_toxic is 0.9829536050196244
# CV score for class obscene is 0.982003717422035
# CV score for class threat is 0.9842271903074215
# CV score for class insult is 0.9753241814834114
# CV score for class identity_hate is 0.9718105388247834
# ITERATION:   121
# Parameters   1.0    17000     (1, 1)    1
# Total score is 0.9776801611525783
# CV score for class toxic is 0.971785665482568
# CV score for class severe_toxic is 0.9824738479080665
# ...
# CV score for class threat is 0.9611372771531085
# CV score for class insult is 0.9446985012530099
# CV score for class identity_hate is 0.9351982082801357
# ITERATION:   159
# Parameters   1.1    1000     (1, 2)    10
# Total score is 0.9505300417172579
# CV score for class toxic is 0.9687992076438979
# CV score for class severe_toxic is 0.9830693770362776
# CV score for class obscene is 0.9813601732132998
# CV score for class threat is 0.984210289024611
# CV score for class insult is 0.9747840298708232
# CV score for class identity_hate is 0.9711519562853255
# ITERATION:   160
# Parameters   1.1    9000     (1, 1)    0.9
# Total score is 0.977229172179039
# CV score for class toxic is 0.9691648546412545
# CV score for class severe_toxic is 0.9831273206622969
# CV score for class obscene is 0.9816156539128406
# CV score for class threat is 0.9846641486930215
# CV score for class insult is 0.9750111635352737
# CV score for class identity_hate is 0.9714530450430018
# ITERATION:   161
# Parameters   1.1    9000     (1, 1)    1
# Total score is 0.9775060310812815
# CV score for class toxic is 0.970507178878632
# CV score for class severe_toxic is 0.9825748565010568
# CV score for class obscene is 0.9819513934087073
# CV score for class threat is 0.9869402942721252
# CV score for class insult is 0.9751588779565329
# CV score for class identity_hate is 0.9715140568106589
# ITERATION:   162
# Parameters   1.1    9000     (1, 1)    3
# Total score is 0.9781077763046189
# CV score for class toxic is 0.969787148065275
# CV score for class severe_toxic is 0.9814101030239474
# CV score for class obscene is 0.9807582844813734
# CV score for class threat is 0.9865286738509065
# CV score for class insult is 0.9738452234031234
# CV score for class identity_hate is 0.9697600348644801
# ITERATION:   163
# Parameters   1.1    9000     (1, 1)    5
# Total score is 0.9770149112815177
# CV score for class toxic is 0.9676849917652514
# CV score for class severe_toxic is 0.9785745806902427
# CV score for class obscene is 0.9779176896602378
# CV score for class threat is 0.984785391955783
# CV score for class insult is 0.970720198308749
# CV score for class identity_hate is 0.9656728024259321
# ITERATION:   164
# Parameters   1.1    9000     (1, 1)    10
# Total score is 0.9742259424676994
# CV score for class toxic is 0.9660165489184193
# CV score for class severe_toxic is 0.982274089221541
# CV score for class obscene is 0.9793109188834942
# CV score for class threat is 0.9838499646947136
# CV score for class insult is 0.9732681416536737
# CV score for class identity_hate is 0.969525650452026
# ITERATION:   165
# Parameters   1.1    9000     (1, 2)    0.9
# Total score is 0.9757075523039779
# CV score for class toxic is 0.9663322329263492
# CV score for class severe_toxic is 0.9823468257870097
# CV score for class obscene is 0.9795578477914585
# CV score for class threat is 0.9843032644872839
# CV score for class insult is 0.9734565106117894
# CV score for class identity_hate is 0.9698019613624176
# ITERATION:   166
# Parameters   1.1    9000     (1, 2)    1
# Total score is 0.9759664404943846
# CV score for class toxic is 0.9669241183203989
# CV score for class severe_toxic is 0.9816357733797657
# CV score for class obscene is 0.9795070816143339
# CV score for class threat is 0.986664627567231
# CV score for class insult is 0.9729017535285932
# CV score for class identity_hate is 0.9694806978571736
# ITERATION:   167
# Parameters   1.1    9000     (1, 2)    3
# Total score is 0.976185675377916
# CV score for class toxic is 0.9657481848844339
# CV score for class severe_toxic is 0.9801094933301816
# CV score for class obscene is 0.9779534181591986
# CV score for class threat is 0.9863283420723379
# CV score for class insult is 0.9710826298638926
# CV score for class identity_hate is 0.9674695200216776
# ITERATION:   168
# Parameters   1.1    9000     (1, 2)    5
# Total score is 0.9747819313886205
# CV score for class toxic is 0.9630030871585888
# CV score for class severe_toxic is 0.9764027933374001
# CV score for class obscene is 0.9745189126958627
# CV score for class threat is 0.9846722644219371
# CV score for class insult is 0.9671673529570696
# CV score for class identity_hate is 0.9627995320825766
# ITERATION:   169
# Parameters   1.1    9000     (1, 2)    10
# Total score is 0.9714273237755724
# CV score for class toxic is 0.9693160608986995
# CV score for class severe_toxic is 0.9828935411520613
# CV score for class obscene is 0.9816848736099733
# CV score for class threat is 0.9837234196597638
# CV score for class insult is 0.9750320030152837
# CV score for class identity_hate is 0.97144191995399
# ITERATION:   170
# Parameters   1.1    17000     (1, 1)    0.9
# Total score is 0.9773486363816285
# CV score for class toxic is 0.969761733858194
# CV score for class severe_toxic is 0.9829536050196244
# CV score for class obscene is 0.982003717422035
# CV score for class threat is 0.9842271903074215
# CV score for class insult is 0.9753241814834114
# CV score for class identity_hate is 0.9718105388247834
# ITERATION:   171
# Parameters   1.1    17000     (1, 1)    1
# Total score is 0.9776801611525783
# CV score for class toxic is 0.971785665482568
# CV score for class severe_toxic is 0.9824738479080665
# CV score for class obscene is 0.9829691474637471
# CV score for class threat is 0.9870091466466334
# CV score for class insult is 0.9760907770002181
# CV score for class identity_hate is 0.9725466924030483
# ITERATION:   172
# Parameters   1.1    17000     (1, 1)    3
# Total score is 0.9788125461507136
# CV score for class toxic is 0.97126276692366
# CV score for class severe_toxic is 0.9813697419860041
# CV score for class obscene is 0.9820720110515709
# CV score for class threat is 0.9867919975913381
# CV score for class insult is 0.974995116960495
# CV score for class identity_hate is 0.9711436557301053
# ITERATION:   173
# Parameters   1.1    17000     (1, 1)    5
# Total score is 0.9779392150405289
# CV score for class toxic is 0.9692258608107323
# CV score for class severe_toxic is 0.9786665945842206
# CV score for class obscene is 0.9795873410892545
# CV score for class threat is 0.9854358107883736
# CV score for class insult is 0.9719942263456233
# CV score for class identity_hate is 0.9675543461375241
# ITERATION:   174
# Parameters   1.1    17000     (1, 1)    10
# Total score is 0.9754106966259547
# CV score for class toxic is 0.9671707756467972
# CV score for class severe_toxic is 0.9820646856538747
# CV score for class obscene is 0.9799627397130903
# CV score for class threat is 0.9833727547941086
# CV score for class insult is 0.9740516504116523
# CV score for class identity_hate is 0.9697079019272111
# ITERATION:   175
# Parameters   1.1    17000     (1, 2)    0.9
# Total score is 0.9760550846911223
# CV score for class toxic is 0.9676008093379981
# CV score for class severe_toxic is 0.9821452459388094
# CV score for class obscene is 0.9803295798119568
# CV score for class threat is 0.9838626817333257
# CV score for class insult is 0.9743405656421533
# CV score for class identity_hate is 0.9700603839092573
# ITERATION:   176
# Parameters   1.1    17000     (1, 2)    1
# Total score is 0.9763898777289168
# CV score for class toxic is 0.969155306368979
# CV score for class severe_toxic is 0.9815975153828153
# CV score for class obscene is 0.9814722266421776
# CV score for class threat is 0.9866229032279169
# CV score for class insult is 0.9747832622677324
# CV score for class identity_hate is 0.9703553843228039
# ITERATION:   177
# Parameters   1.1    17000     (1, 2)    3
# Total score is 0.977331099702071
# CV score for class toxic is 0.9682028412778513
# CV score for class severe_toxic is 0.9801909525000397
# CV score for class obscene is 0.9804160250882775
# CV score for class threat is 0.986462169446438
# CV score for class insult is 0.9733109197301203
# CV score for class identity_hate is 0.9685680100527878
# ITERATION:   178
# Parameters   1.1    17000     (1, 2)    5
# Total score is 0.9761918196825858
# CV score for class toxic is 0.9654839229791699
# CV score for class severe_toxic is 0.9766524269556629
# CV score for class obscene is 0.9775516188669539
# CV score for class threat is 0.9850733502331831
# CV score for class insult is 0.969634972334584
# CV score for class identity_hate is 0.9643237603010549
# ITERATION:   179
# Parameters   1.1    17000     (1, 2)    10
# Total score is 0.9731200086117681
# CV score for class toxic is 0.9693060738252862
# CV score for class severe_toxic is 0.9830009811088223
# CV score for class obscene is 0.9818472658073484
# CV score for class threat is 0.983235044362328
# CV score for class insult is 0.9749804929944555
# CV score for class identity_hate is 0.9715988422106107
# ITERATION:   180
# Parameters   1.1    25000     (1, 1)    0.9
# Total score is 0.9773281167181419
# CV score for class toxic is 0.9697882703306213
# CV score for class severe_toxic is 0.9830739662680367
# CV score for class obscene is 0.9822041507831946
# CV score for class threat is 0.9837411409901974
# CV score for class insult is 0.9753012914668594
# CV score for class identity_hate is 0.9720031059967389
# ITERATION:   181
# Parameters   1.1    25000     (1, 1)    1
# Total score is 0.9776853209726081
# CV score for class toxic is 0.9721749088070916
# CV score for class severe_toxic is 0.9827515204871831
# CV score for class obscene is 0.983592162351766
# CV score for class threat is 0.9866172125569763
# CV score for class insult is 0.9763877438244065
# CV score for class identity_hate is 0.9732951671843547
# ITERATION:   182
# Parameters   1.1    25000     (1, 1)    3
# Total score is 0.9791364525352964
# CV score for class toxic is 0.9718243400335931
# CV score for class severe_toxic is 0.9817398141018273
# CV score for class obscene is 0.9829043984300911
# CV score for class threat is 0.986438348286021
# CV score for class insult is 0.9754367430575056
# CV score for class identity_hate is 0.9722026662496797
# ITERATION:   183
# Parameters   1.1    25000     (1, 1)    5
# Total score is 0.978424385026453
# CV score for class toxic is 0.9700381864748772
# CV score for class severe_toxic is 0.979191802280286
# CV score for class obscene is 0.9807396234911958
# CV score for class threat is 0.9851412503740248
# CV score for class insult is 0.972590536107707
# CV score for class identity_hate is 0.9691532289442009
# ITERATION:   184
# Parameters   1.1    25000     (1, 1)    10
# Total score is 0.9761424379453819
# CV score for class toxic is 0.9671601450503825
# CV score for class severe_toxic is 0.9824264614282431
# CV score for class obscene is 0.9797058374251183
# CV score for class threat is 0.9832867792618986
# CV score for class insult is 0.9739477832515441
# CV score for class identity_hate is 0.9691552868756075
# ITERATION:   185
# Parameters   1.1    25000     (1, 2)    0.9
# Total score is 0.9759470488821324
# CV score for class toxic is 0.9676516397183028
# CV score for class severe_toxic is 0.9825045584164428
# CV score for class obscene is 0.9801209906606404
# CV score for class threat is 0.983799336204681
# CV score for class insult is 0.9742883954688463
# CV score for class identity_hate is 0.9695713707150491
# ITERATION:   186
# Parameters   1.1    25000     (1, 2)    1
# Total score is 0.9763227151973272
# CV score for class toxic is 0.9697413602738402
# CV score for class severe_toxic is 0.9821004172471116
# CV score for class obscene is 0.9816415345196495
# CV score for class threat is 0.9869626245716332
# CV score for class insult is 0.9752267673795334
# CV score for class identity_hate is 0.9704467229943016
# ITERATION:   187
# Parameters   1.1    25000     (1, 2)    3
# Total score is 0.9776865711643449
# CV score for class toxic is 0.9689875236461022
# CV score for class severe_toxic is 0.9808922254964411
# CV score for class obscene is 0.9807353345129638
# CV score for class threat is 0.986973947850486
# CV score for class insult is 0.9739994621136905
# CV score for class identity_hate is 0.9690131074600131
# ITERATION:   188
# Parameters   1.1    25000     (1, 2)    5
# Total score is 0.9767669335132827
# CV score for class toxic is 0.9665178918581129
# CV score for class severe_toxic is 0.9778547329674087
# CV score for class obscene is 0.9781589144254558
# CV score for class threat is 0.9858946122381961
# CV score for class insult is 0.9706672580007414
# CV score for class identity_hate is 0.9654556559884959
# ITERATION:   189
# Parameters   1.1    25000     (1, 2)    10
# Total score is 0.9740915109130684
# CV score for class toxic is 0.9692539474373367
# CV score for class severe_toxic is 0.9829949171669577
# CV score for class obscene is 0.9819058553696567
# CV score for class threat is 0.9827996116754542
# CV score for class insult is 0.9749071837508723
# CV score for class identity_hate is 0.9717737230430181
# ITERATION:   190
# Parameters   1.1    33000     (1, 1)    0.9
# Total score is 0.9772725397405493
# CV score for class toxic is 0.9697530516896403
# CV score for class severe_toxic is 0.983067090711506
# CV score for class obscene is 0.9822907525708624
# CV score for class threat is 0.9833277801605855
# CV score for class insult is 0.9752448783593701
# CV score for class identity_hate is 0.9721937016955536
# ITERATION:   191
# Parameters   1.1    33000     (1, 1)    1
# Total score is 0.9776462091979198
# CV score for class toxic is 0.9723486092939314
# CV score for class severe_toxic is 0.9827776849370092
# CV score for class obscene is 0.9839356585724762
# CV score for class threat is 0.9864528101804068
# CV score for class insult is 0.9764931747512243
# CV score for class identity_hate is 0.9736464986651194
# ITERATION:   192
# Parameters   1.1    33000     (1, 1)    3
# Total score is 0.9792757394000279
# CV score for class toxic is 0.9720965634583667
# CV score for class severe_toxic is 0.9818063570994436
# CV score for class obscene is 0.9833762905383386
# CV score for class threat is 0.9863854190176017
# CV score for class insult is 0.9756123658913628
# CV score for class identity_hate is 0.9726729411450297
# ITERATION:   193
# Parameters   1.1    33000     (1, 1)    5
# Total score is 0.9786583228583572
# CV score for class toxic is 0.9704388740720686
# CV score for class severe_toxic is 0.9793454925256398
# CV score for class obscene is 0.9814088056067943
# CV score for class threat is 0.985275127163468
# CV score for class insult is 0.9728393507437962
# CV score for class identity_hate is 0.9698659551697126
# ITERATION:   194
# Parameters   1.1    33000     (1, 1)    10
# Total score is 0.9765289342135799
# CV score for class toxic is 0.9672008346239268
# CV score for class severe_toxic is 0.9822811467155432
# CV score for class obscene is 0.9795722999643143
# CV score for class threat is 0.9828360448668785
# CV score for class insult is 0.9738390040853604
# CV score for class identity_hate is 0.9687821930298236
# ITERATION:   195
# Parameters   1.1    33000     (1, 2)    0.9
# Total score is 0.975751920547641
# CV score for class toxic is 0.9677360015430209
# CV score for class severe_toxic is 0.9823609388153655
# CV score for class obscene is 0.9800143393644823
# CV score for class threat is 0.9833698244642477
# CV score for class insult is 0.9742074564722278
# CV score for class identity_hate is 0.9692336571528865
# ITERATION:   196
# Parameters   1.1    33000     (1, 2)    1
# Total score is 0.9761537029687051
# CV score for class toxic is 0.9702864604240272
# CV score for class severe_toxic is 0.9820699021594375
# CV score for class obscene is 0.9818561032793057
# CV score for class threat is 0.9867236924917577
# CV score for class insult is 0.9754552918804035
# CV score for class identity_hate is 0.9704699845453627
# ITERATION:   197
# Parameters   1.1    33000     (1, 2)    3
# Total score is 0.977810239130049
# CV score for class toxic is 0.9697459056373239
# CV score for class severe_toxic is 0.9809961837223353
# CV score for class obscene is 0.9811049668920164
# CV score for class threat is 0.9867702187670618
# CV score for class insult is 0.9743795142563267
# CV score for class identity_hate is 0.9691938148565334
# ITERATION:   198
# Parameters   1.1    33000     (1, 2)    5
# Total score is 0.9770317673552662
# CV score for class toxic is 0.9676075013744603
# CV score for class severe_toxic is 0.9782550106260134
# CV score for class obscene is 0.9787945351673636
# CV score for class threat is 0.9857422113660667
# CV score for class insult is 0.9712878080603592
# CV score for class identity_hate is 0.9659602209550912
# ITERATION:   199
# Parameters   1.1    33000     (1, 2)    10
# Total score is 0.9746078812582257

# %%
df_res = df_res.fillna(0)    


br=[]
for i in df_res.columns:
    br.append(max(df_res[i]))

print(br)
print(np.mean(br))
# Out:
# [0.97234860929393141, 0.98312732066229691, 0.98393565857247622, 0.98700914664663342, 0.97649317475122432, 0.97364649866511943]
# 0.979426734765

# %%
# SEARCHING THE BEST SET OF PARAMETERS WHEN  tfidf__max_features IN  np.arange(40000, 50000, 5000)



total_score = []

df_res = pd.DataFrame(columns=class_names)
df_res = df_res.append({class_name: cv_score}, ignore_index=True)

for tfidf__max_df in np.arange(0.8, 1.1, 0.1):
    for tfidf__max_features in np.arange(40000, 50000, 5000):
        for tfidf__ngram_range in ((1, 1), (1, 2)):
            for lr__C in [0.9,1,3,5,10]:
                word_vectorizer = TfidfVectorizer(
                    analyzer='word', 
                    ngram_range=tfidf__ngram_range, 
                    vocabulary=None, 
                    max_df=tfidf__max_df,
                    max_features=tfidf__max_features, 
                    smooth_idf=True,
                    norm='l2' 
                    )


                classifier = LogisticRegression(penalty = 'l2', C = lr__C,max_iter = 1000)
                
                word_vectorizer.fit(all_text)
                train_word_features = word_vectorizer.transform(train_text)
                test_word_features = word_vectorizer.transform(test_text)
                
                scores= []
                d={}
                
                for class_name in class_names:
                    train_target = train[class_name]

                    cv_score = np.mean(cross_val_score(classifier, train_word_features, train_target, scoring='roc_auc'))
                    
                    
                    print('CV score for class {} is {}'.format(class_name, cv_score))
                    
                    d[class_name] = cv_score
                    
                    
                    scores.append(cv_score)
                df_res = df_res.append(d, ignore_index=True)
                d.clear()
                #print(df_res)
                print('ITERATION:  ',len(total_score))
                print('Parameters  ',tfidf__max_df,'  ',tfidf__max_features,'   ',tfidf__ngram_range,'  ',lr__C)
                total_score.append(np.mean(scores))
                print('Total score is {}'.format(np.mean(scores)))
# Out:
# CV score for class toxic is 0.9691492919755298
# CV score for class severe_toxic is 0.9829615169479098
# CV score for class obscene is 0.9818470654092436
# CV score for class threat is 0.9825722563751427
# CV score for class insult is 0.9747557613384066
# CV score for class identity_hate is 0.9715294679713439
# ITERATION:   0
# Parameters   0.8    40000     (1, 1)    0.9
# Total score is 0.9771358933362627
# CV score for class toxic is 0.9696565427638314
# CV score for class severe_toxic is 0.9830343593583223
# CV score for class obscene is 0.9822356511359415
# CV score for class threat is 0.9830972118746493
# CV score for class insult is 0.9750978213109104
# CV score for class identity_hate is 0.9719650524344831
# ITERATION:   1
# Parameters   0.8    40000     (1, 1)    1
# Total score is 0.9775144398130231
# CV score for class toxic is 0.9723321296665891
# CV score for class severe_toxic is 0.9827843286885942
# CV score for class obscene is 0.9839690824300448
# CV score for class threat is 0.986317374089804
# CV score for class insult is 0.9764095169177861
# CV score for class identity_hate is 0.9734676809642896
# ITERATION:   2
# Parameters   0.8    40000     (1, 1)    3
# Total score is 0.9792133521261847
# CV score for class toxic is 0.9721242598192865
# CV score for class severe_toxic is 0.9818609458068436
# CV score for class obscene is 0.983457076752363
# CV score for class threat is 0.986287344385648
# CV score for class insult is 0.9755477264426493
# CV score for class identity_hate is 0.9725304395164875
# ITERATION:   3
# Parameters   0.8    40000     (1, 1)    5
# Total score is 0.9786346321205462
# CV score for class toxic is 0.970543695074752
# CV score for class severe_toxic is 0.9795318755682928
# CV score for class obscene is 0.9815610615681427
# CV score for class threat is 0.98523619355567
# CV score for class insult is 0.9727698898584739
# CV score for class identity_hate is 0.9698070443825636
# ITERATION:   4
# Parameters   0.8    40000     (1, 1)    10
# Total score is 0.9765749600013159
# CV score for class toxic is 0.9671898996637077
# CV score for class severe_toxic is 0.9822220725387076
# CV score for class obscene is 0.9793670321299995
# CV score for class threat is 0.9830586412225483
# CV score for class insult is 0.97368762282305
# CV score for class identity_hate is 0.9688342572095113
# ITERATION:   5
# Parameters   0.8    40000     (1, 2)    0.9
# Total score is 0.9757265875979207
# CV score for class toxic is 0.9677614555915302
# CV score for class severe_toxic is 0.9823020625300963
# CV score for class obscene is 0.9798309032122967
# CV score for class threat is 0.983600261058294
# CV score for class insult is 0.9740792063600964
# CV score for class identity_hate is 0.9693167290718541
# ITERATION:   6
# Parameters   0.8    40000     (1, 2)    1
# Total score is 0.9761484363040281
# CV score for class toxic is 0.9706183518031283
# CV score for class severe_toxic is 0.9820836049919098
# CV score for class obscene is 0.9819003195216954
# CV score for class threat is 0.9871118715094731
# CV score for class insult is 0.975530080459028
# CV score for class identity_hate is 0.9708315127725701
# ITERATION:   7
# Parameters   0.8    40000     (1, 2)    3
# Total score is 0.9780126235096341
# CV score for class toxic is 0.9702152242018345
# CV score for class severe_toxic is 0.9811330515469591
# CV score for class obscene is 0.9812731194933401
# CV score for class threat is 0.9872872648467114
# CV score for class insult is 0.9745580673465106
# CV score for class identity_hate is 0.9697156969975477
# ITERATION:   8
# Parameters   0.8    40000     (1, 2)    5
# Total score is 0.9773637374054839
# CV score for class toxic is 0.9682904716265989
# CV score for class severe_toxic is 0.9787406306716001
# CV score for class obscene is 0.9791669966634008
# CV score for class threat is 0.9865158876308137
# CV score for class insult is 0.9716506766988665
# CV score for class identity_hate is 0.9667988613810885
# ITERATION:   9
# Parameters   0.8    40000     (1, 2)    10
# Total score is 0.9751939207787279
# CV score for class toxic is 0.9690937107466896
# CV score for class severe_toxic is 0.9828864132115253
# CV score for class obscene is 0.9818037372039602
# CV score for class threat is 0.9825215191713546
# CV score for class insult is 0.9746634549667946
# CV score for class identity_hate is 0.9713976916901564
# ITERATION:   10
# Parameters   0.8    45000     (1, 1)    0.9
# Total score is 0.9770610878317467
# CV score for class toxic is 0.9696049110957783
# CV score for class severe_toxic is 0.9829567491637402
# CV score for class obscene is 0.9822022742686473
# CV score for class threat is 0.9830559895952239
# CV score for class insult is 0.9750101446782891
# CV score for class identity_hate is 0.9718376091195404
# ITERATION:   11
# Parameters   0.8    45000     (1, 1)    1
# Total score is 0.9774446129868699
# CV score for class toxic is 0.9723363386240239
# CV score for class severe_toxic is 0.9826884167850546
# CV score for class obscene is 0.9839769270001413
# CV score for class threat is 0.9863071777278565
# CV score for class insult is 0.9763765051541266
# CV score for class identity_hate is 0.9734385419794509
# ITERATION:   12
# Parameters   0.8    45000     (1, 1)    3
# Total score is 0.9791873178784423
# CV score for class toxic is 0.9721519256529453
# CV score for class severe_toxic is 0.9817648497280772
# CV score for class obscene is 0.983482243144039
# CV score for class threat is 0.9862957353580262
# CV score for class insult is 0.9755431353241323
# CV score for class identity_hate is 0.9725164921260734
# ITERATION:   13
# Parameters   0.8    45000     (1, 1)    5
# Total score is 0.9786257302222156
# CV score for class toxic is 0.9706130626955235
# CV score for class severe_toxic is 0.9794395175543427
# CV score for class obscene is 0.9816171614162635
# CV score for class threat is 0.9852800983470095
# CV score for class insult is 0.9728345026185393
# CV score for class identity_hate is 0.9697856271592872
# ITERATION:   14
# Parameters   0.8    45000     (1, 1)    10
# Total score is 0.9765949949651609
# CV score for class toxic is 0.9672057854321773
# CV score for class severe_toxic is 0.9821714012545386
# CV score for class obscene is 0.9795289134699695
# CV score for class threat is 0.9828899644187784
# CV score for class insult is 0.973774689521188
# CV score for class identity_hate is 0.9688358889706553
# ITERATION:   15
# Parameters   0.8    45000     (1, 2)    0.9
# Total score is 0.9757344405112179
# CV score for class toxic is 0.9677954114719318
# CV score for class severe_toxic is 0.9822496837533841
# CV score for class obscene is 0.9800121127018205
# CV score for class threat is 0.9834419738304643
# CV score for class insult is 0.9741776018822322
# CV score for class identity_hate is 0.9693300688635907
# ITERATION:   16
# Parameters   0.8    45000     (1, 2)    1
# Total score is 0.9761678087505706
# CV score for class toxic is 0.970842763635071
# CV score for class severe_toxic is 0.9820259341855669
# CV score for class obscene is 0.9822845274860535
# CV score for class threat is 0.9870496617924953
# CV score for class insult is 0.9757473329422228
# CV score for class identity_hate is 0.9710797068586404
# ITERATION:   17
# Parameters   0.8    45000     (1, 2)    3
# Total score is 0.9781716544833418
# CV score for class toxic is 0.9705379808309419
# CV score for class severe_toxic is 0.9810900061269158
# CV score for class obscene is 0.9817632948248108
# CV score for class threat is 0.9872647539341234
# CV score for class insult is 0.9748532526871846
# CV score for class identity_hate is 0.9701084314450212
# ITERATION:   18
# Parameters   0.8    45000     (1, 2)    5
# Total score is 0.9776029533081664
# CV score for class toxic is 0.9687776037184713
# CV score for class severe_toxic is 0.978735224759873
# CV score for class obscene is 0.9798291383876553
# CV score for class threat is 0.9865415238167922
# CV score for class insult is 0.9720917441785035
# CV score for class identity_hate is 0.9674440765768085
# ITERATION:   19
# Parameters   0.8    45000     (1, 2)    10
# Total score is 0.9755698852396839
# CV score for class toxic is 0.9691492919755298
# CV score for class severe_toxic is 0.9829615169479098
# CV score for class obscene is 0.9818470654092436
# CV score for class threat is 0.9825722563751427
# CV score for class insult is 0.9747557613384066
# CV score for class identity_hate is 0.9715294679713439
# ITERATION:   20
# Parameters   0.9    40000     (1, 1)    0.9
# Total score is 0.9771358933362627
# CV score for class toxic is 0.9696565427638314
# CV score for class severe_toxic is 0.9830343593583223
# CV score for class obscene is 0.9822356511359415
# CV score for class threat is 0.9830972118746493
# CV score for class insult is 0.9750978213109104
# CV score for class identity_hate is 0.9719650524344831
# ITERATION:   21
# Parameters   0.9    40000     (1, 1)    1
# Total score is 0.9775144398130231
# CV score for class toxic is 0.9723321296665891
# CV score for class severe_toxic is 0.9827843286885942
# CV score for class obscene is 0.9839690824300448
# CV score for class threat is 0.986317374089804
# CV score for class insult is 0.9764095169177861
# CV score for class identity_hate is 0.9734676809642896
# ITERATION:   22
# Parameters   0.9    40000     (1, 1)    3
# Total score is 0.9792133521261847
# CV score for class toxic is 0.9721242598192865
# CV score for class severe_toxic is 0.9818609458068436
# CV score for class obscene is 0.983457076752363
# CV score for class threat is 0.986287344385648
# CV score for class insult is 0.9755477264426493
# CV score for class identity_hate is 0.9725304395164875
# ITERATION:   23
# Parameters   0.9    40000     (1, 1)    5
# Total score is 0.9786346321205462
# CV score for class toxic is 0.970543695074752
# CV score for class severe_toxic is 0.9795318755682928
# CV score for class obscene is 0.9815610615681427
# CV score for class threat is 0.98523619355567
# CV score for class insult is 0.9727698898584739
# CV score for class identity_hate is 0.9698070443825636
# ITERATION:   24
# Parameters   0.9    40000     (1, 1)    10
# Total score is 0.9765749600013159
# CV score for class toxic is 0.9671898996637077
# CV score for class severe_toxic is 0.9822220725387076
# CV score for class obscene is 0.9793670321299995
# CV score for class threat is 0.9830586412225483
# CV score for class insult is 0.97368762282305
# CV score for class identity_hate is 0.9688342572095113
# ITERATION:   25
# Parameters   0.9    40000     (1, 2)    0.9
# Total score is 0.9757265875979207
# CV score for class toxic is 0.9677614555915302
# CV score for class severe_toxic is 0.9823020625300963
# CV score for class obscene is 0.9798309032122967
# CV score for class threat is 0.983600261058294
# CV score for class insult is 0.9740792063600964
# CV score for class identity_hate is 0.9693167290718541
# ITERATION:   26
# Parameters   0.9    40000     (1, 2)    1
# Total score is 0.9761484363040281
# CV score for class toxic is 0.9706183518031283
# CV score for class severe_toxic is 0.9820836049919098
# CV score for class obscene is 0.9819003195216954
# CV score for class threat is 0.9871118715094731
# CV score for class insult is 0.975530080459028
# CV score for class identity_hate is 0.9708315127725701
# ITERATION:   27
# Parameters   0.9    40000     (1, 2)    3
# Total score is 0.9780126235096341
# CV score for class toxic is 0.9702152242018345
# CV score for class severe_toxic is 0.9811330515469591
# CV score for class obscene is 0.9812731194933401
# CV score for class threat is 0.9872872648467114
# CV score for class insult is 0.9745580673465106
# CV score for class identity_hate is 0.9697156969975477
# ITERATION:   28
# Parameters   0.9    40000     (1, 2)    5
# Total score is 0.9773637374054839
# CV score for class toxic is 0.9682904716265989
# CV score for class severe_toxic is 0.9787406306716001
# CV score for class obscene is 0.9791669966634008
# CV score for class threat is 0.9865158876308137
# CV score for class insult is 0.9716506766988665
# CV score for class identity_hate is 0.9667988613810885
# ITERATION:   29
# Parameters   0.9    40000     (1, 2)    10
# Total score is 0.9751939207787279
# CV score for class toxic is 0.9690937107466896
# CV score for class severe_toxic is 0.9828864132115253
# CV score for class obscene is 0.9818037372039602
# CV score for class threat is 0.9825215191713546
# CV score for class insult is 0.9746634549667946
# CV score for class identity_hate is 0.9713976916901564
# ITERATION:   30
# Parameters   0.9    45000     (1, 1)    0.9
# Total score is 0.9770610878317467
# CV score for class toxic is 0.9696049110957783
# CV score for class severe_toxic is 0.9829567491637402
# CV score for class obscene is 0.9822022742686473
# CV score for class threat is 0.9830559895952239
# CV score for class insult is 0.9750101446782891
# CV score for class identity_hate is 0.9718376091195404
# ITERATION:   31
# Parameters   0.9    45000     (1, 1)    1
# Total score is 0.9774446129868699
# CV score for class toxic is 0.9723363386240239
# CV score for class severe_toxic is 0.9826884167850546
# CV score for class obscene is 0.9839769270001413
# CV score for class threat is 0.9863071777278565
# CV score for class insult is 0.9763765051541266
# CV score for class identity_hate is 0.9734385419794509
# ITERATION:   32
# Parameters   0.9    45000     (1, 1)    3
# Total score is 0.9791873178784423
# CV score for class toxic is 0.9721519256529453
# CV score for class severe_toxic is 0.9817648497280772
# CV score for class obscene is 0.983482243144039
# CV score for class threat is 0.9862957353580262
# CV score for class insult is 0.9755431353241323
# CV score for class identity_hate is 0.9725164921260734
# ITERATION:   33
# Parameters   0.9    45000     (1, 1)    5
# Total score is 0.9786257302222156
# CV score for class toxic is 0.9706130626955235
# CV score for class severe_toxic is 0.9794395175543427
# CV score for class obscene is 0.9816171614162635
# CV score for class threat is 0.9852800983470095
# CV score for class insult is 0.9728345026185393
# CV score for class identity_hate is 0.9697856271592872
# ITERATION:   34
# Parameters   0.9    45000     (1, 1)    10
# Total score is 0.9765949949651609
# CV score for class toxic is 0.9672057854321773
# CV score for class severe_toxic is 0.9821714012545386
# CV score for class obscene is 0.9795289134699695
# CV score for class threat is 0.9828899644187784
# CV score for class insult is 0.973774689521188
# CV score for class identity_hate is 0.9688358889706553
# ITERATION:   35
# Parameters   0.9    45000     (1, 2)    0.9
# Total score is 0.9757344405112179
# CV score for class toxic is 0.9677954114719318
# CV score for class severe_toxic is 0.9822496837533841
# CV score for class obscene is 0.9800121127018205
# CV score for class threat is 0.9834419738304643
# CV score for class insult is 0.9741776018822322
# CV score for class identity_hate is 0.9693300688635907
# ITERATION:   36
# Parameters   0.9    45000     (1, 2)    1
# Total score is 0.9761678087505706
# CV score for class toxic is 0.970842763635071
# CV score for class severe_toxic is 0.9820259341855669
# CV score for class obscene is 0.9822845274860535
# CV score for class threat is 0.9870496617924953
# CV score for class insult is 0.9757473329422228
# CV score for class identity_hate is 0.9710797068586404
# ITERATION:   37
# Parameters   0.9    45000     (1, 2)    3
# Total score is 0.9781716544833418
# CV score for class toxic is 0.9705379808309419
# CV score for class severe_toxic is 0.9810900061269158
# CV score for class obscene is 0.9817632948248108
# CV score for class threat is 0.9872647539341234
# CV score for class insult is 0.9748532526871846
# CV score for class identity_hate is 0.9701084314450212
# ITERATION:   38
# Parameters   0.9    45000     (1, 2)    5
# Total score is 0.9776029533081664
# CV score for class toxic is 0.9687776037184713
# CV score for class severe_toxic is 0.978735224759873
# CV score for class obscene is 0.9798291383876553
# CV score for class threat is 0.9865415238167922
# CV score for class insult is 0.9720917441785035
# CV score for class identity_hate is 0.9674440765768085
# ITERATION:   39
# Parameters   0.9    45000     (1, 2)    10
# Total score is 0.9755698852396839
# CV score for class toxic is 0.9691492919755298
# CV score for class severe_toxic is 0.9829615169479098
# CV score for class obscene is 0.9818470654092436
# CV score for class threat is 0.9825722563751427
# CV score for class insult is 0.9747557613384066
# CV score for class identity_hate is 0.9715294679713439
# ITERATION:   40
# Parameters   1.0    40000     (1, 1)    0.9
# Total score is 0.9771358933362627
# CV score for class toxic is 0.9696565427638314
# CV score for class severe_toxic is 0.9830343593583223
# CV score for class obscene is 0.9822356511359415
# CV score for class threat is 0.9830972118746493
# CV score for class insult is 0.9750978213109104
# CV score for class identity_hate is 0.9719650524344831
# ITERATION:   41
# Parameters   1.0    40000     (1, 1)    1
# Total score is 0.9775144398130231
# CV score for class toxic is 0.9723321296665891
# CV score for class severe_toxic is 0.9827843286885942
# CV score for class obscene is 0.9839690824300448
# CV score for class threat is 0.986317374089804
# CV score for class insult is 0.9764095169177861
# CV score for class identity_hate is 0.9734676809642896
# ITERATION:   42
# Parameters   1.0    40000     (1, 1)    3
# Total score is 0.9792133521261847
# CV score for class toxic is 0.9721242598192865
# CV score for class severe_toxic is 0.9818609458068436
# CV score for class obscene is 0.983457076752363
# CV score for class threat is 0.986287344385648
# CV score for class insult is 0.9755477264426493
# CV score for class identity_hate is 0.9725304395164875
# ITERATION:   43
# Parameters   1.0    40000     (1, 1)    5
# Total score is 0.9786346321205462
# CV score for class toxic is 0.970543695074752
# CV score for class severe_toxic is 0.9795318755682928
# CV score for class obscene is 0.9815610615681427
# CV score for class threat is 0.98523619355567
# CV score for class insult is 0.9727698898584739
# CV score for class identity_hate is 0.9698070443825636
# ITERATION:   44
# Parameters   1.0    40000     (1, 1)    10
# Total score is 0.9765749600013159
# CV score for class toxic is 0.9671898996637077
# CV score for class severe_toxic is 0.9822220725387076
# CV score for class obscene is 0.9793670321299995
# CV score for class threat is 0.9830586412225483
# CV score for class insult is 0.97368762282305
# CV score for class identity_hate is 0.9688342572095113
# ITERATION:   45
# Parameters   1.0    40000     (1, 2)    0.9
# Total score is 0.9757265875979207
# CV score for class toxic is 0.9677614555915302
# CV score for class severe_toxic is 0.9823020625300963
# CV score for class obscene is 0.9798309032122967
# CV score for class threat is 0.983600261058294
# CV score for class insult is 0.9740792063600964
# CV score for class identity_hate is 0.9693167290718541
# ITERATION:   46
# Parameters   1.0    40000     (1, 2)    1
# Total score is 0.9761484363040281
# CV score for class toxic is 0.9706183518031283
# CV score for class severe_toxic is 0.9820836049919098
# CV score for class obscene is 0.9819003195216954
# CV score for class threat is 0.9871118715094731
# CV score for class insult is 0.975530080459028
# CV score for class identity_hate is 0.9708315127725701
# ITERATION:   47
# Parameters   1.0    40000     (1, 2)    3
# Total score is 0.9780126235096341
# CV score for class toxic is 0.9702152242018345
# CV score for class severe_toxic is 0.9811330515469591
# CV score for class obscene is 0.9812731194933401
# CV score for class threat is 0.9872872648467114
# CV score for class insult is 0.9745580673465106
# CV score for class identity_hate is 0.9697156969975477
# ITERATION:   48
# Parameters   1.0    40000     (1, 2)    5
# Total score is 0.9773637374054839
# CV score for class toxic is 0.9682904716265989
# CV score for class severe_toxic is 0.9787406306716001
# CV score for class obscene is 0.9791669966634008
# CV score for class threat is 0.9865158876308137
# CV score for class insult is 0.9716506766988665
# CV score for class identity_hate is 0.9667988613810885
# ITERATION:   49
# Parameters   1.0    40000     (1, 2)    10
# Total score is 0.9751939207787279
# CV score for class toxic is 0.9690937107466896
# CV score for class severe_toxic is 0.9828864132115253
# CV score for class obscene is 0.9818037372039602
# CV score for class threat is 0.9825215191713546
# CV score for class insult is 0.9746634549667946
# CV score for class identity_hate is 0.9713976916901564
# ITERATION:   50
# Parameters   1.0    45000     (1, 1)    0.9
# Total score is 0.9770610878317467
# CV score for class toxic is 0.9696049110957783
# CV score for class severe_toxic is 0.9829567491637402
# CV score for class obscene is 0.9822022742686473
# CV score for class threat is 0.9830559895952239
# CV score for class insult is 0.9750101446782891
# CV score for class identity_hate is 0.9718376091195404
# ITERATION:   51
# Parameters   1.0    45000     (1, 1)    1
# Total score is 0.9774446129868699
# CV score for class toxic is 0.9723363386240239
# CV score for class severe_toxic is 0.9826884167850546
# CV score for class obscene is 0.9839769270001413
# CV score for class threat is 0.9863071777278565
# CV score for class insult is 0.9763765051541266
# CV score for class identity_hate is 0.9734385419794509
# ITERATION:   52
# Parameters   1.0    45000     (1, 1)    3
# Total score is 0.9791873178784423
# CV score for class toxic is 0.9721519256529453
# CV score for class severe_toxic is 0.9817648497280772
# CV score for class obscene is 0.983482243144039
# CV score for class threat is 0.9862957353580262
# CV score for class insult is 0.9755431353241323
# CV score for class identity_hate is 0.9725164921260734
# ITERATION:   53
# Parameters   1.0    45000     (1, 1)    5
# Total score is 0.9786257302222156
# CV score for class toxic is 0.9706130626955235
# CV score for class severe_toxic is 0.9794395175543427
# CV score for class obscene is 0.9816171614162635
# CV score for class threat is 0.9852800983470095
# CV score for class insult is 0.9728345026185393
# CV score for class identity_hate is 0.9697856271592872
# ITERATION:   54
# Parameters   1.0    45000     (1, 1)    10
# Total score is 0.9765949949651609
# CV score for class toxic is 0.9672057854321773
# CV score for class severe_toxic is 0.9821714012545386
# CV score for class obscene is 0.9795289134699695
# CV score for class threat is 0.9828899644187784
# CV score for class insult is 0.973774689521188
# CV score for class identity_hate is 0.9688358889706553
# ITERATION:   55
# Parameters   1.0    45000     (1, 2)    0.9
# Total score is 0.9757344405112179
# CV score for class toxic is 0.9677954114719318
# CV score for class severe_toxic is 0.9822496837533841
# CV score for class obscene is 0.9800121127018205
# CV score for class threat is 0.9834419738304643
# CV score for class insult is 0.9741776018822322
# CV score for class identity_hate is 0.9693300688635907
# ITERATION:   56
# Parameters   1.0    45000     (1, 2)    1
# Total score is 0.9761678087505706
# CV score for class toxic is 0.970842763635071
# CV score for class severe_toxic is 0.9820259341855669
# CV score for class obscene is 0.9822845274860535
# CV score for class threat is 0.9870496617924953
# CV score for class insult is 0.9757473329422228
# CV score for class identity_hate is 0.9710797068586404
# ITERATION:   57
# Parameters   1.0    45000     (1, 2)    3
# Total score is 0.9781716544833418
# CV score for class toxic is 0.9705379808309419
# CV score for class severe_toxic is 0.9810900061269158
# CV score for class obscene is 0.9817632948248108
# CV score for class threat is 0.9872647539341234
# CV score for class insult is 0.9748532526871846
# CV score for class identity_hate is 0.9701084314450212
# ITERATION:   58
# Parameters   1.0    45000     (1, 2)    5
# Total score is 0.9776029533081664
# CV score for class toxic is 0.9687776037184713
# CV score for class severe_toxic is 0.978735224759873
# CV score for class obscene is 0.9798291383876553
# CV score for class threat is 0.9865415238167922
# CV score for class insult is 0.9720917441785035
# CV score for class identity_hate is 0.9674440765768085
# ITERATION:   59
# Parameters   1.0    45000     (1, 2)    10
# Total score is 0.9755698852396839
# CV score for class toxic is 0.9691492919755298
# CV score for class severe_toxic is 0.9829615169479098
# CV score for class obscene is 0.9818470654092436
# CV score for class threat is 0.9825722563751427
# CV score for class insult is 0.9747557613384066
# CV score for class identity_hate is 0.9715294679713439
# ITERATION:   60
# Parameters   1.1    40000     (1, 1)    0.9
# Total score is 0.9771358933362627
# CV score for class toxic is 0.9696565427638314
# CV score for class severe_toxic is 0.9830343593583223
# CV score for class obscene is 0.9822356511359415
# CV score for class threat is 0.9830972118746493
# CV score for class insult is 0.9750978213109104
# CV score for class identity_hate is 0.9719650524344831
# ITERATION:   61
# Parameters   1.1    40000     (1, 1)    1
# Total score is 0.9775144398130231
# CV score for class toxic is 0.9723321296665891
# CV score for class severe_toxic is 0.9827843286885942
# CV score for class obscene is 0.9839690824300448
# CV score for class threat is 0.986317374089804
# CV score for class insult is 0.9764095169177861
# CV score for class identity_hate is 0.9734676809642896
# ITERATION:   62
# Parameters   1.1    40000     (1, 1)    3
# Total score is 0.9792133521261847
# CV score for class toxic is 0.9721242598192865
# CV score for class severe_toxic is 0.9818609458068436
# CV score for class obscene is 0.983457076752363
# CV score for class threat is 0.986287344385648
# CV score for class insult is 0.9755477264426493
# CV score for class identity_hate is 0.9725304395164875
# ITERATION:   63
# Parameters   1.1    40000     (1, 1)    5
# Total score is 0.9786346321205462
# CV score for class toxic is 0.970543695074752
# CV score for class severe_toxic is 0.9795318755682928
# CV score for class obscene is 0.9815610615681427
# CV score for class threat is 0.98523619355567
# CV score for class insult is 0.9727698898584739
# CV score for class identity_hate is 0.9698070443825636
# ITERATION:   64
# Parameters   1.1    40000     (1, 1)    10
# Total score is 0.9765749600013159
# CV score for class toxic is 0.9671898996637077
# CV score for class severe_toxic is 0.9822220725387076
# CV score for class obscene is 0.9793670321299995
# CV score for class threat is 0.9830586412225483
# CV score for class insult is 0.97368762282305
# CV score for class identity_hate is 0.9688342572095113
# ITERATION:   65
# Parameters   1.1    40000     (1, 2)    0.9
# Total score is 0.9757265875979207
# CV score for class toxic is 0.9677614555915302
# CV score for class severe_toxic is 0.9823020625300963
# CV score for class obscene is 0.9798309032122967
# CV score for class threat is 0.983600261058294
# CV score for class insult is 0.9740792063600964
# CV score for class identity_hate is 0.9693167290718541
# ITERATION:   66
# Parameters   1.1    40000     (1, 2)    1
# Total score is 0.9761484363040281
# CV score for class toxic is 0.9706183518031283
# CV score for class severe_toxic is 0.9820836049919098
# CV score for class obscene is 0.9819003195216954
# CV score for class threat is 0.9871118715094731
# CV score for class insult is 0.975530080459028
# CV score for class identity_hate is 0.9708315127725701
# ITERATION:   67
# Parameters   1.1    40000     (1, 2)    3
# Total score is 0.9780126235096341
# CV score for class toxic is 0.9702152242018345
# CV score for class severe_toxic is 0.9811330515469591
# CV score for class obscene is 0.9812731194933401
# CV score for class threat is 0.9872872648467114
# CV score for class insult is 0.9745580673465106
# CV score for class identity_hate is 0.9697156969975477
# ITERATION:   68
# Parameters   1.1    40000     (1, 2)    5
# Total score is 0.9773637374054839
# CV score for class toxic is 0.9682904716265989
# CV score for class severe_toxic is 0.9787406306716001
# CV score for class obscene is 0.9791669966634008
# CV score for class threat is 0.9865158876308137
# CV score for class insult is 0.9716506766988665
# CV score for class identity_hate is 0.9667988613810885
# ITERATION:   69
# Parameters   1.1    40000     (1, 2)    10
# Total score is 0.9751939207787279
# CV score for class toxic is 0.9690937107466896
# CV score for class severe_toxic is 0.9828864132115253
# CV score for class obscene is 0.9818037372039602
# CV score for class threat is 0.9825215191713546
# CV score for class insult is 0.9746634549667946
# CV score for class identity_hate is 0.9713976916901564
# ITERATION:   70
# Parameters   1.1    45000     (1, 1)    0.9
# Total score is 0.9770610878317467
# CV score for class toxic is 0.9696049110957783
# CV score for class severe_toxic is 0.9829567491637402
# CV score for class obscene is 0.9822022742686473
# CV score for class threat is 0.9830559895952239
# CV score for class insult is 0.9750101446782891
# CV score for class identity_hate is 0.9718376091195404
# ITERATION:   71
# Parameters   1.1    45000     (1, 1)    1
# Total score is 0.9774446129868699
# CV score for class toxic is 0.9723363386240239
# CV score for class severe_toxic is 0.9826884167850546
# CV score for class obscene is 0.9839769270001413
# CV score for class threat is 0.9863071777278565
# CV score for class insult is 0.9763765051541266
# CV score for class identity_hate is 0.9734385419794509
# ITERATION:   72
# Parameters   1.1    45000     (1, 1)    3
# Total score is 0.9791873178784423
# CV score for class toxic is 0.9721519256529453
# CV score for class severe_toxic is 0.9817648497280772
# CV score for class obscene is 0.983482243144039
# CV score for class threat is 0.9862957353580262
# CV score for class insult is 0.9755431353241323
# CV score for class identity_hate is 0.9725164921260734
# ITERATION:   73
# Parameters   1.1    45000     (1, 1)    5
# Total score is 0.9786257302222156
# CV score for class toxic is 0.9706130626955235
# CV score for class severe_toxic is 0.9794395175543427
# CV score for class obscene is 0.9816171614162635
# CV score for class threat is 0.9852800983470095
# CV score for class insult is 0.9728345026185393
# CV score for class identity_hate is 0.9697856271592872
# ITERATION:   74
# Parameters   1.1    45000     (1, 1)    10
# Total score is 0.9765949949651609
# CV score for class toxic is 0.9672057854321773
# CV score for class severe_toxic is 0.9821714012545386
# CV score for class obscene is 0.9795289134699695
# CV score for class threat is 0.9828899644187784
# CV score for class insult is 0.973774689521188
# CV score for class identity_hate is 0.9688358889706553
# ITERATION:   75
# Parameters   1.1    45000     (1, 2)    0.9
# Total score is 0.9757344405112179
# CV score for class toxic is 0.9677954114719318
# CV score for class severe_toxic is 0.9822496837533841
# CV score for class obscene is 0.9800121127018205
# CV score for class threat is 0.9834419738304643
# CV score for class insult is 0.9741776018822322
# CV score for class identity_hate is 0.9693300688635907
# ITERATION:   76
# Parameters   1.1    45000     (1, 2)    1
# Total score is 0.9761678087505706
# CV score for class toxic is 0.970842763635071
# CV score for class severe_toxic is 0.9820259341855669
# CV score for class obscene is 0.9822845274860535
# CV score for class threat is 0.9870496617924953
# CV score for class insult is 0.9757473329422228
# CV score for class identity_hate is 0.9710797068586404
# ITERATION:   77
# Parameters   1.1    45000     (1, 2)    3
# Total score is 0.9781716544833418
# CV score for class toxic is 0.9705379808309419
# CV score for class severe_toxic is 0.9810900061269158
# CV score for class obscene is 0.9817632948248108
# CV score for class threat is 0.9872647539341234
# CV score for class insult is 0.9748532526871846
# CV score for class identity_hate is 0.9701084314450212
# ITERATION:   78
# Parameters   1.1    45000     (1, 2)    5
# Total score is 0.9776029533081664
# CV score for class toxic is 0.9687776037184713
# CV score for class severe_toxic is 0.978735224759873
# CV score for class obscene is 0.9798291383876553
# CV score for class threat is 0.9865415238167922
# CV score for class insult is 0.9720917441785035
# CV score for class identity_hate is 0.9674440765768085
# ITERATION:   79
# Parameters   1.1    45000     (1, 2)    10
# Total score is 0.9755698852396839

# %%
df_res = df_res.fillna(0)

br=[]
for i in df_res.columns:
    br.append(max(df_res[i]))

print(br)
print(np.mean(br))
# Out:
# [0.97233633862402391, 0.98303435935832228, 0.98397692700014128, 0.98728726484671137, 0.9764095169177861, 0.97346768096428959]
# 0.979418681285

# %% [markdown]
# Для классификации будем использовать логистическую регрессию [LogisticRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html).

# %% [markdown]
# Будем тренировать по одному классификатору на каждый класс.
#
# Что бы провалидировать качество модели воспользуемся функцией [cross_val_score](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html)

# %%
#TASK3 CV ON THE BEST SET OF PARAMETERS, FOUNDED PREVIOUSLY

scores= []

for class_name in class_names:
    train_target = train[class_name]
    
    if class_name == 'toxic':
        word_vectorizer = TfidfVectorizer(
                    analyzer='word', 
                    ngram_range=(1, 1), 
                    vocabulary=None, 
                    max_df=0.8, 
                    max_features=33000 , 
                    smooth_idf=True,
                    norm='l2' 
                    )

        classifier = LogisticRegression(penalty = 'l2', C = 3,max_iter = 5000)
        
    elif class_name == 'severe_toxic':
        word_vectorizer = TfidfVectorizer(
                    analyzer='word', 
                    ngram_range=(1, 1), 
                    vocabulary=None, 
                    max_df=0.8, 
                    max_features=9000, 
                    smooth_idf=True,
                    norm='l2' 
                    )

        classifier = LogisticRegression(penalty = 'l2', C = 1,max_iter = 5000)
    
    elif class_name == 'obscene':
        word_vectorizer = TfidfVectorizer(
                    analyzer='word', 
                    ngram_range=(1, 1), 
                    vocabulary=None, 
                    max_df=0.8, 
                    max_features=45000 , 
                    smooth_idf=True,
                    norm='l2' 
                    )

        classifier = LogisticRegression(penalty = 'l2', C = 3,max_iter = 5000)
        
    elif class_name == 'threat':
        word_vectorizer = TfidfVectorizer(
                    analyzer='word', 
                    ngram_range=(1, 2), 
                    vocabulary=None, 
                    max_df=0.8, 
                    max_features=40000 , 
                    smooth_idf=True,
                    norm='l2' 
                    )

        classifier = LogisticRegression(penalty = 'l2', C = 5,max_iter = 5000)
        
    elif class_name == 'insult':
        word_vectorizer = TfidfVectorizer(
                    analyzer='word', 
                    ngram_range=(1, 1), 
                    vocabulary=None, 
                    max_df=0.8, 
                    max_features=33000 , 
                    smooth_idf=True,
                    norm='l2' 
                    )

        classifier = LogisticRegression(penalty = 'l2', C = 3,max_iter = 5000)
        
    elif class_name == 'identity_hate':
        word_vectorizer = TfidfVectorizer(
                    analyzer='word', 
                    ngram_range=(1, 1), 
                    vocabulary=None, 
                    max_df=0.8, 
                    max_features=40000, 
                    smooth_idf=True,
                    norm='l2' 
                    )

        classifier = LogisticRegression(penalty = 'l2', C = 3,max_iter = 5000)
        
    word_vectorizer.fit(all_text)
    train_word_features = word_vectorizer.transform(train_text)
    
    cv_score = np.mean(cross_val_score(classifier, train_word_features, train_target, scoring='roc_auc'))
    
    print('CV score for class {} is {}'.format(class_name, cv_score))
    scores.append(cv_score)

print('Total score is {}'.format(np.mean(scores)))
# Out:
# CV score for class toxic is 0.9723486092939314
# CV score for class severe_toxic is 0.9831273206622969
# CV score for class obscene is 0.9839769270001413
# CV score for class threat is 0.9872872648467114
# CV score for class insult is 0.9764931747512243
# CV score for class identity_hate is 0.9734676809642896
# Total score is 0.9794501629197659

# %% [markdown]
# Попробуйте подобрать лучшие параметры для `word_vectorizer` и `classifier` оптимизируя метрику [ROC AUC](https://en.wikipedia.org/wiki/Receiver_operating_characteristic)

# %% [markdown]
# ---

# %% [markdown]
# Опубликуйте лучшие решение на [Kaggle Toxic Comment Classification Challenge](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge/submit)

# %%
submission = pd.DataFrame.from_dict({'id': test['id']})

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from scipy.sparse import hstack

class_names = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

train = pd.read_csv('train.csv').fillna(' ')
test = pd.read_csv('test.csv').fillna(' ')

train_text = train['comment_text']
test_text = test['comment_text']
all_text = pd.concat([train_text, test_text])

word_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    strip_accents='unicode',
    analyzer='word',
    token_pattern=r'\w{1,}',
    stop_words='english',
    ngram_range=(1, 1),
    max_features=10000)
word_vectorizer.fit(all_text)
train_word_features = word_vectorizer.transform(train_text)
test_word_features = word_vectorizer.transform(test_text)

char_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    strip_accents='unicode',
    analyzer='char',
    stop_words='english',
    ngram_range=(2, 6),
    max_features=50000)
char_vectorizer.fit(all_text)
train_char_features = char_vectorizer.transform(train_text)
test_char_features = char_vectorizer.transform(test_text)

train_features = hstack([train_char_features, train_word_features])
test_features = hstack([test_char_features, test_word_features])

scores = []
submission = pd.DataFrame.from_dict({'id': test['id']})
for class_name in class_names:
    train_target = train[class_name]
    classifier = LogisticRegression(solver='sag')

    cv_score = np.mean(cross_val_score(classifier, train_features, train_target, cv=3, scoring='roc_auc'))
    scores.append(cv_score)
    print('CV score for class {} is {}'.format(class_name, cv_score))

    classifier.fit(train_features, train_target)
    submission[class_name] = classifier.predict_proba(test_features)[:, 1]

print('Total CV score is {}'.format(np.mean(scores)))

submission.to_csv('submission.csv', index=False)
# Out:
# CV score for class toxic is 0.9783248627763198
# CV score for class severe_toxic is 0.9885336069890597
# CV score for class obscene is 0.9901305860590298
# CV score for class threat is 0.9896536828692066
# CV score for class insult is 0.9826307233013799
# CV score for class identity_hate is 0.9823772016603595
# Total CV score is 0.9852751106092258
